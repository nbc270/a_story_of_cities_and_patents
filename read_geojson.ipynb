# %% [markdown]
# # Notebook Plan
#
# This notebook creates all necessary files to run the d3 map visualization seen on our website.
# https://sarahjune1.github.io/CUSP_innovation_capstone/map.html
#
# 1. Read in geoJSON of all city shapes
# 2. Create summary file and city stats file
# 3. GeoJSON w/ city locations. i.e. Drop all stats

# %%
import geopandas as gpd
import pandas as pd
from fiona.crs import from_epsg

# %% [markdown]
# ## 1. Read in city geoJSON file

# %%
patent_cities = gpd.read_file('patent_cities.geojson')

# %%
patent_cities.head()
# Out:
#    bbox_east  bbox_north  bbox_south  bbox_west  \
# 0 -73.700181   40.916179   40.477399 -74.259090
# 1 -73.694626   41.165357   41.100336 -73.733743
# 2 -73.823639   41.024019   41.000791 -73.853932
# 3 -73.893042   42.843668   42.763577 -73.983475
# 4 -77.029932   42.164366   42.131597 -77.075799
#
#                                           place_name  comma_count county_flag  \
# 0                       New York City, New York, USA            2     no_flag
# 1  Armonk, Town of North Castle, Westchester Coun...            5     no_flag
# 2  Ardsley, Town of Greenburgh, Westchester Count...            5     no_flag
# 3     Schenectady, Schenectady County, New York, USA            3     no_flag
# 4             Corning, Steuben County, New York, USA            3     no_flag
#
#           city    state     name postal  fips      city_state  \
# 0      newyork  NewYork  NewYork     ny    36      newyork_ny
# 1       armonk  NewYork  NewYork     ny    36       armonk_ny
# 2      ardsley  NewYork  NewYork     ny    36      ardsley_ny
# 3  schenectady  NewYork  NewYork     ny    36  schenectady_ny
# 4      corning  NewYork  NewYork     ny    36      corning_ny
#
#                                             geometry
# 0  (POLYGON ((-74.25909 40.497207, -74.259089 40....
# 1  POLYGON ((-73.733743 41.118404, -73.733743 41....
# 2  POLYGON ((-73.853932 41.005698, -73.8539070000...
# 3  POLYGON ((-73.9834749 42.8015698, -73.98047 42...
# 4  POLYGON ((-77.075799 42.158076, -77.075709 42....

# %%
patent_cities.shape
# Out:
# (2496, 14)

# %% [markdown]
# ## 2. Create summary csv file and city stats JSON

# %%
df_stats= pd.read_csv('pre_scaling_data.csv')
df_stats.drop(['Unnamed: 0'], axis = 1, inplace = True)
df_stats.drop_duplicates(subset=['city_state', 'Year'], inplace = True)

# %%
cities = pd.DataFrame(df_stats.city_state.value_counts()).reset_index()
cities = list((cities.loc[cities.city_state > 11])['index'])

# %%
cities_to_keep = df_stats.loc[df_stats.city_state.isin(cities)]
cities_to_keep.head()
# Out:
#       Award Mean  Award Sum  Company Count  Year     city_state  \
# 0  128725.714286   901080.0            7.0  2001  santaclara_ca
# 1  166188.029412  5650393.0           34.0  2001     houston_tx
# 2  238464.416667  5723146.0           24.0  2001     sanjose_ca
# 3  253001.500000  7590045.0           30.0  2001   sunnyvale_ca
# 4  175075.826087  4026744.0           23.0  2001     newyork_ny
#
#    creative_employees  creative_establishments  empowerment_zone  \
# 0              2222.0                    188.0                 0
# 1             45344.0                  11568.0                 1
# 2             10299.0                   1751.0                 0
# 3              1416.0                    176.0                 0
# 4            309161.0                  25930.0                 1
#
#    median_household_income  performance_amount        ...         \
# 0                  69466.0        8.192436e+06        ...
# 1                  36616.0        4.012357e+08        ...
# 2                  70243.0        2.071373e+05        ...
# 3                  74409.0        6.085471e+07        ...
# 4                  38293.0        2.300854e+06        ...
#
#    percent_creative_class  scaled_perc_creative_class  \
# 0                0.013904                    0.016659
# 1                0.015419                    0.022965
# 2                0.023521                    0.030553
# 3                0.015296                    0.017492
# 4                0.039986                    0.063421
#
#    creative_establishment_ratio  company_count_perc  percent_bachelors  \
# 0                      0.028060            0.001045           0.241177
# 1                      0.050016            0.000147           0.157040
# 2                      0.048380            0.000663           0.191269
# 3                      0.029033            0.004949           0.278218
# 4                      0.035639            0.000032           0.153664
#
#    percent_graduate  percent_foreign_born  scaled_population  recipient_mean  \
# 0          0.146017              0.348707          11.536261    1.995343e+05
# 1          0.082908              0.264177          14.485200    6.299981e+05
# 2          0.094006              0.368467          13.704515    3.977885e+05
# 3          0.203854              0.394581          11.788737    1.432841e+06
# 4          0.102363              0.358508          15.895986    2.086376e+05
#
#    performance_mean
# 0      4.096218e+06
# 1      2.994297e+06
# 2      2.071373e+04
# 3      6.761635e+06
# 4      1.870613e+04
#
# [5 rows x 33 columns]

# %%
cities_to_keep.city_state.value_counts()
# Out:
# maplegrove_mn           12
# evansville_in           12
# kenosha_wi              12
# watsonville_ca          12
# columbia_mo             12
# sancarlos_ca            12
# rockville_md            12
# irvine_ca               12
# malibu_ca               12
# alpharetta_ga           12
# seattle_wa              12
# monrovia_ca             12
# fortcollins_co          12
# milpitas_ca             12
# aurora_il               12
# newhaven_ct             12
# henderson_nv            12
# rockford_il             12
# raleigh_nc              12
# albuquerque_nm          12
# warsaw_in               12
# campbell_ca             12
# emeryville_ca           12
# melbourne_fl            12
# stpaul_mn               12
# fallschurch_va          12
# tampa_fl                12
# franklin_tn             12
# menlopark_ca            12
# norfolk_va              12
#                         ..
# chulavista_ca           12
# livonia_mi              12
# dallas_tx               12
# santaclara_ca           12
# loveland_co             12
# pawtucket_ri            12
# southportland_me        12
# littleton_co            12
# bellingham_wa           12
# eugene_or               12
# newyork_ny              12
# boston_ma               12
# manchester_nh           12
# bothell_wa              12
# sanrafael_ca            12
# corvallis_or            12
# southsanfrancisco_ca    12
# houston_tx              12
# hillsboro_or            12
# chapelhill_nc           12
# greensboro_nc           12
# plano_tx                12
# waltham_ma              12
# paloalto_ca             12
# albany_ny               12
# spokane_wa              12
# omaha_ne                12
# sidney_oh               12
# chesterfield_mo         12
# sanantonio_tx           12
# Name: city_state, dtype: int64

# %%
all_data = pd.read_csv('patent_data_all_years.csv')
all_data = all_data.loc[(all_data.Year > 2000) & (all_data.Year < 2013)]
all_data.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'], axis = 1, inplace = True)
all_data.head()
# Out:
#               City  Inv_to_Assignee_ratio  Patents State  Year  \
# 25000  Santa Clara               0.276342     4603    CA  2001
# 25001       Armonk               0.004720     4237    NY  2001
# 25002      Houston               0.342191     3989    TX  2001
# 25003     San Jose               1.772214     2656    CA  2001
# 25004        Boise               0.848334     2011    ID  2001
#
#        assignee_IPC_A  assignee_IPC_B  assignee_IPC_C  assignee_IPC_D  \
# 25000        0.028660        0.033437        0.171443        0.004984
# 25001        0.004449        0.029543        0.010856        0.001602
# 25002        0.018820        0.108391        0.087732        0.009622
# 25003        0.008116        0.023188        0.014493        0.005797
# 25004        0.003608        0.102391        0.032927        0.000902
#
#        assignee_IPC_E                 ...                  \
# 25000        0.000727                 ...
# 25001        0.000712                 ...
# 25002        0.260648                 ...
# 25003        0.000000                 ...
# 25004        0.000451                 ...
#
#        pt_statutory invention registration  pt_utility  Rank  \
# 25000                             0.000217    0.987617     0
# 25001                             0.000000    0.997640     1
# 25002                             0.000251    0.990474     2
# 25003                             0.000000    0.990211     3
# 25004                             0.000000    0.996519     4
#
#        assignee_patent_annual_sum  inventor_patent_annual_sum  \
# 25000                       98990                      121057
# 25001                       98990                      121057
# 25002                       98990                      121057
# 25003                       98990                      121057
# 25004                       98990                      121057
#
#        inventor_patents_perc  assignee_patents_perc  inventor_rank  \
# 25000               0.010507               0.046500             11
# 25001               0.000165               0.042802            723
# 25002               0.011276               0.040297             10
# 25003               0.038883               0.026831              0
# 25004               0.014093               0.020315              7
#
#        assignee_pats_citations_normalized  inventor_pats_citations_normalized
# 25000                            0.056873                            0.008476
# 25001                            0.019063                            0.000357
# 25002                            0.050546                            0.020757
# 25003                            0.022082                            0.036183
# 25004                            0.009612                            0.005238
#
# [5 rows x 48 columns]

# %%
city_vals = pd.DataFrame(all_data.city_state.value_counts()).reset_index()
city_vals = city_vals.loc[city_vals.city_state > 11]
city_vals = list(city_vals['index'])
len(city_vals)
# Out:
# 550

# %%
all_data = all_data.loc[all_data.city_state.isin(city_vals)]
all_data.city_state.value_counts()
# Out:
# ('Newark', 'DE')              12
# ('Palo Alto', 'CA')           12
# ('Farmington Hills', 'MI')    12
# ('New York', 'NY')            12
# ('Vienna', 'VA')              12
# ('Northbrook', 'IL')          12
# ('San Marcos', 'CA')          12
# ('South Gate', 'CA')          12
# ('Zeeland', 'MI')             12
# ('Tokyo', None)               12
# ('West Chester', 'OH')        12
# ('Staten Island', 'NY')       12
# ('Knoxville', 'TN')           12
# ('San Clemente', 'CA')        12
# ('Logan', 'UT')               12
# ('Urbana', 'IL')              12
# ('Latham', 'NY')              12
# ('Waukesha', 'WI')            12
# ('Tustin', 'CA')              12
# ('Akron', 'OH')               12
# ('Latrobe', 'PA')             12
# ('Rancho Dominguez', 'CA')    12
# ('Glen Allen', 'VA')          12
# ('Naples', 'FL')              12
# ('Minneapolis', 'MN')         12
# ('Tallahassee', 'FL')         12
# ('Elkhart', 'IN')             12
# ('Glenview', 'IL')            12
# ('Islandia', 'NY')            12
# ('Aurora', 'IL')              12
#                               ..
# ('North Hollywood', 'CA')     12
# ('Westbury', 'NY')            12
# ('Mundelein', 'IL')           12
# ('Lawrence', 'KS')            12
# ('City of Industry', 'CA')    12
# ('Lowell', 'MA')              12
# ('Philadelphia', 'PA')        12
# ('Racine', 'WI')              12
# ('San Luis Obispo', 'CA')     12
# ('Greenville', 'SC')          12
# ('Appleton', 'WI')            12
# ('Chatsworth', 'CA')          12
# ('Sullivan', 'IL')            12
# ('University Park', 'PA')     12
# ('Boulder', 'CO')             12
# ('Florham Park', 'NJ')        12
# ('North Haven', 'CT')         12
# ('Chapel Hill', 'NC')         12
# ('Mansfield', 'MA')           12
# ('White Plains', 'NY')        12
# ('Kent', 'WA')                12
# ('Longmont', 'CO')            12
# ('Oxnard', 'CA')              12
# ('Birmingham', 'AL')          12
# ('Santa Rosa', 'CA')          12
# ('York', 'PA')                12
# ('Jacksonville', 'FL')        12
# ('Pleasanton', 'CA')          12
# ('Burlington', 'MA')          12
# ('San Rafael', 'CA')          12
# Name: city_state, dtype: int64

# %%
all_data = all_data[['City', 'State', 'Year', 'Patents', 'assignee_pats_cited',
                             'inventor_patents', 'inventor_pats_cited']]
all_data = all_data[pd.notnull(all_data['City'])]
all_data = all_data[pd.notnull(all_data['State'])]

# %%
all_data['city_for_viewing'] = all_data['City'] + ', ' + all_data['State']
all_data['City'] = all_data.City.apply(lambda x: str.lower(x))
all_data['City'] = all_data.City.apply(lambda x: x.replace(' ', ''))
all_data['State'] = all_data.State.apply(lambda x: str.lower(x))
all_data['city_state'] = all_data['City'] + '_' + all_data['State']
all_data.drop(['City', 'State'], axis = 1, inplace = True)

# %%
all_data.drop(['assignee_pats_cited', 'inventor_pats_cited'], axis = 1, inplace = True)

# %%
cities_to_keep = cities_to_keep.merge(all_data, on = ['Year', 'city_state'], how = 'inner')

# %%
cities_to_keep.head()
# Out:
#       Award Mean  Award Sum  Company Count  Year     city_state  \
# 0  128725.714286   901080.0            7.0  2001  santaclara_ca
# 1  166188.029412  5650393.0           34.0  2001     houston_tx
# 2  238464.416667  5723146.0           24.0  2001     sanjose_ca
# 3  253001.500000  7590045.0           30.0  2001   sunnyvale_ca
# 4  175075.826087  4026744.0           23.0  2001     newyork_ny
#
#    creative_employees  creative_establishments  empowerment_zone  \
# 0              2222.0                    188.0                 0
# 1             45344.0                  11568.0                 1
# 2             10299.0                   1751.0                 0
# 3              1416.0                    176.0                 0
# 4            309161.0                  25930.0                 1
#
#    median_household_income  performance_amount        ...         \
# 0                  69466.0        8.192436e+06        ...
# 1                  36616.0        4.012357e+08        ...
# 2                  70243.0        2.071373e+05        ...
# 3                  74409.0        6.085471e+07        ...
# 4                  38293.0        2.300854e+06        ...
#
#    company_count_perc  percent_bachelors  percent_graduate  \
# 0            0.001045           0.241177          0.146017
# 1            0.000147           0.157040          0.082908
# 2            0.000663           0.191269          0.094006
# 3            0.004949           0.278218          0.203854
# 4            0.000032           0.153664          0.102363
#
#    percent_foreign_born  scaled_population  recipient_mean  performance_mean  \
# 0              0.348707          11.536261    1.995343e+05      4.096218e+06
# 1              0.264177          14.485200    6.299981e+05      2.994297e+06
# 2              0.368467          13.704515    3.977885e+05      2.071373e+04
# 3              0.394581          11.788737    1.432841e+06      6.761635e+06
# 4              0.358508          15.895986    2.086376e+05      1.870613e+04
#
#    Patents  inventor_patents  city_for_viewing
# 0     4603              1272   Santa Clara, CA
# 1     3989              1365       Houston, TX
# 2     2656              4707      San Jose, CA
# 3     2000              2581     Sunnyvale, CA
# 4     1806              1110      New York, NY
#
# [5 rows x 36 columns]

# %%
cities_to_keep.columns
# Out:
# Index([u'Award Mean', u'Award Sum', u'Company Count', u'Year', u'city_state',
#        u'creative_employees', u'creative_establishments', u'empowerment_zone',
#        u'median_household_income', u'performance_amount', u'performance_count',
#        u'recipient_amount', u'recipient_count', u'regular_employees',
#        u'regular_establishments', u'total_earned_bachelor',
#        u'total_earned_graduate_degree', u'total_foreign',
#        u'total_less_than_bachelor', u'total_native', u'total_population',
#        u'Score_invented', u'Score_assigned', u'percent_creative_class',
#        u'scaled_perc_creative_class', u'creative_establishment_ratio',
#        u'company_count_perc', u'percent_bachelors', u'percent_graduate',
#        u'percent_foreign_born', u'scaled_population', u'recipient_mean',
#        u'performance_mean', u'Patents', u'inventor_patents',
#        u'city_for_viewing'],
#       dtype='object')

# %%
cities_to_keep.to_csv('csv_for_summary.csv')

# %% [markdown]
# #### Create city_stats.json

# %%
df_stats_dict = {}
for year in list(cities_to_keep.Year.unique()):
    
    temp_df = cities_to_keep.loc[cities_to_keep.Year == year]
    temp_df.set_index('city_state', inplace = True)
    temp_dict = temp_df.to_dict(orient = 'index')
    df_stats_dict[year] = temp_dict

# %%
import json
with open('city_stats.json', 'w') as fp:
    json.dump(df_stats_dict, fp)

# %% [markdown]
# ## 3. GeoJSON w/ city locations. i.e. Drop all stats

# %%
cities_to_keep = df_stats.loc[df_stats.city_state.isin(cities)]
cities_to_keep = cities_to_keep.drop_duplicates(subset = 'city_state', keep = 'first')
cities_to_keep_gdf = gpd.GeoDataFrame(cities_to_keep)
cities_to_keep_gdf.crs = from_epsg(4326)

# %%
df_only_cities = cities_to_keep_gdf[['city_state', 'Year']]
only_geometries = patent_cities.merge(df_only_cities, on = 'city_state', how = 'inner')
only_geometries = only_geometries.drop_duplicates(subset = 'city_state', keep = 'first')
only_geometries.head()
# Out:
#    bbox_east  bbox_north  bbox_south  bbox_west  \
# 0 -73.700181   40.916179   40.477399 -74.259090
# 2 -73.893042   42.843668   42.763577 -73.983475
# 3 -73.719524   41.069796   40.982445 -73.789848
# 4 -78.795168   42.966469   42.826039 -78.919453
# 5 -76.074084   43.086102   42.984371 -76.204603
#
#                                         place_name  comma_count county_flag  \
# 0                     New York City, New York, USA            2     no_flag
# 2   Schenectady, Schenectady County, New York, USA            3     no_flag
# 3  White Plains, Westchester County, New York, USA            3     no_flag
# 4              Buffalo, Erie County, New York, USA            3     no_flag
# 5         Syracuse, Onondaga County, New York, USA            3     no_flag
#
#           city    state     name postal  fips      city_state  \
# 0      newyork  NewYork  NewYork     ny    36      newyork_ny
# 2  schenectady  NewYork  NewYork     ny    36  schenectady_ny
# 3  whiteplains  NewYork  NewYork     ny    36  whiteplains_ny
# 4      buffalo  NewYork  NewYork     ny    36      buffalo_ny
# 5     syracuse  NewYork  NewYork     ny    36     syracuse_ny
#
#                                             geometry  Year
# 0  (POLYGON ((-74.25909 40.497207, -74.259089 40....  2001
# 2  POLYGON ((-73.9834749 42.8015698, -73.98047 42...  2001
# 3  POLYGON ((-73.78984800000001 41.029136, -73.78...  2001
# 4  POLYGON ((-78.9194528 42.9471686, -78.91906040...  2001
# 5  POLYGON ((-76.2046029 43.0452075, -76.20459219...  2001

# %%
only_geometries['centroid'] = only_geometries.geometry.apply(lambda x: x.centroid)
only_geometries['lat'] = only_geometries.centroid.y
only_geometries['lon'] = only_geometries.centroid.x
only_geometries.drop(['centroid'], axis = 1, inplace = True)

# %%
only_geometries.columns
# Out:
# Index([  u'bbox_east',  u'bbox_north',  u'bbox_south',   u'bbox_west',
#         u'place_name', u'comma_count', u'county_flag',        u'city',
#              u'state',        u'name',      u'postal',        u'fips',
#         u'city_state',    u'geometry',        u'Year',         u'lat',
#                u'lon'],
#       dtype='object')

# %%
only_geometries.shape
# Out:
# (297, 17)

# %%
only_geometries.to_file('cities_geo.geojson', driver = 'GeoJSON')
