# %%
import pandas as pd
import numpy as np
from collections import Counter
import itertools
import ast
from ast import literal_eval
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /nfshome/tc1767/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /nfshome/tc1767/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /nfshome/tc1767/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#output a directory for each patent's city and ipc section matched with its index number so that we can use the 
#index number to extract rows from dataframe for each city and ipc section
def get_directory(df):
    for i in range(len(df)):
        ipc = literal_eval(df['IPCs'][i])
        for j in range(len(ipc)):  
            sec = ipc[j]['ipc_section']
            try:
                asgn = literal_eval(df['assignees'][i])
                for k in range(len(asgn)):
                    yield (i, (asgn[k]['assignee_city'], sec))
            except SyntaxError:
                asgn = df.iloc[i]['assignees']
                for k in range(asgn.count('city')):
                    yield (i, (asgn.split(':')[2+k*3].split(',')[0][3:-1], sec))

# %%
#implement dataframe to get corresponding directory
directory = sorted(list(set(get_directory(df))), key=lambda x: x[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-21a5d91e3fbb> in <module>
#       1 #implement dataframe to get corresponding directory
# ----> 2 directory = sorted(list(set(get_directory(df))), key=lambda x: x[0])
#
# NameError: name 'df' is not defined

# %%
#output a list of tuples with unique values (city or ipc section) and corresponding number of patents
#num: 0-city, 1-ipc section
def count_unique(directory, num):
    counts = {}
    for tup in directory:
        counts[tup[1][num]] = counts.get(tup[1][num], 0) + 1
    return sorted(counts.items(), key=lambda x: x[1], reverse=True)

# %%
#df: compete dataframe with all patents
#directory: directory we get from above
#num: 0-city, 1-ipc section
#string: city or ipc section that we want to refine
def df_by_index(df, directory, num, string):
    return df.iloc[list(map(lambda x: x[0], filter(lambda x: x[1][num]==string, directory)))]

# %%
def df_by_2index(df, directory, city, field):
    cities = list(map(lambda x: x[0], filter(lambda x: x[1][0]==city, directory)))
    fields = list(map(lambda x: x[0], filter(lambda x: x[1][1]==field, directory)))
    return df.iloc[list(set(cities) & set(fields))]

# %% [markdown]
# #### IPC Sections:
# A = Human Necessitites,
# B = Performing Operations; Transporint,
# C = Chemistry; Metallurgy,
# D = Textiles; paper,
# E = Fixed Constructing,
# F = Mechanical Engineering; Lighting; Heating; Weapons; Blasting Engines; Pumps,
# G = Physics,
# H = Electricity

# %%
def tokenize_words(df):
    stop_words = stopwords.words('english')
    allwords = []
    for i in list(df.index):
        try:
            words = [x.lower() for x in nltk.word_tokenize(df.loc[i]['patent_abstract']) if x.isalnum()]
            allwords.append([word for word in words if not word in stop_words])
        except:
            continue
    return list(itertools.chain.from_iterable(allwords))

# %%
def words_dict(df):
    rawcounts = dict(Counter([x for x in tokenize_words(df)]))
    pos = dict(nltk.pos_tag(rawcounts.keys()))    
    d = {}
    for key in rawcounts.keys():
        try:
            d.setdefault(key,[]).append(rawcounts[key])        
        except KeyError:
            pass

        try:
            d.setdefault(key,[]).append(pos[key])          
        except KeyError:
            pass
    return d

# %% [markdown]
# ### For 2008

# %%
pat08 = pd.read_csv("/projects/cps2019_funding/shared/Patents_Data/cityAnalysis/cleaned_patent_years/patents2008_full.csv")

# %%
dir08 = sorted(list(set(get_directory(pat08))), key=lambda x: x[0])

# %%
top10 = list(map(lambda x: x[0], count_unique(dir08, 0)[:10]))

# %%
top10
# Out:
# ['Armonk',
#  'Houston',
#  'San Jose',
#  'Santa Clara',
#  'Redmond',
#  'San Diego',
#  'Sunnyvale',
#  'Atlanta',
#  'Wilmington',
#  'Mountain View']

# %%
ipcs = list(map(lambda x: x[0], count_unique(dir08, 1)))

# %%
ipcs
# Out:
# ['G', 'H', 'A', 'B', 'C', None, 'F', 'E', 'D', 'R']

# %%
Armonk_G_08 = words_dict(df_by_2index(pat08, dir08, top10[0], ipcs[0]))

# %%
sorted(Armonk_G_08.items(),key=lambda x: x[1][0], reverse=True)
# Out:
# [('data', [9296, 'NNS']),
#  ('system', [7377, 'NN']),
#  ('one', [6189, 'CD']),
#  ('method', [5956, 'NN']),
#  ('first', [5224, 'RB']),
#  ('second', [3549, 'JJ']),
#  ('includes', [3441, 'VBZ']),
#  ('user', [3240, 'RBR']),
#  ('computer', [3069, 'NN']),
#  ('least', [2858, 'JJS']),
#  ('memory', [2837, 'NN']),
#  ('information', [2788, 'NN']),
#  ('may', [2687, 'MD']),
#  ('plurality', [2487, 'NN']),
#  ('set', [2476, 'VBD']),
#  ('device', [2470, 'NN']),
#  ('processing', [2295, 'NN']),
#  ('storage', [2252, 'NN']),
#  ('associated', [2245, 'VBN']),
#  ('program', [2058, 'NN']),
#  ('provided', [2055, 'VBD']),
#  ('application', [2049, 'NN']),
#  ('based', [2009, 'VBN']),
#  ('request', [1528, 'NN']),
#  ('server', [1503, 'NN']),
#  ('within', [1468, 'IN']),
#  ('using', [1461, 'VBG']),
#  ('virtual', [1446, 'JJ']),
#  ('object', [1404, 'NN']),
#  ('access', [1403, 'NN']),
#  ('processor', [1351, 'NN']),
#  ('process', [1348, 'NN']),
#  ('value', [1336, 'NN']),
#  ('unit', [1336, 'NN']),
#  ('response', [1322, 'NN']),
#  ('time', [1314, 'NN']),
#  ('code', [1305, 'NN']),
#  ('invention', [1290, 'NN']),
#  ('message', [1259, 'NN']),
#  ('network', [1254, 'NN']),
#  ('service', [1247, 'NN']),
#  ('include', [1228, 'VB']),
#  ('cache', [1218, 'VBP']),
#  ('control', [1204, 'NN']),
#  ('selected', [1194, 'VBN']),
#  ('apparatus', [1173, 'JJ']),
#  ('file', [1172, 'NN']),
#  ('wherein', [1156, 'NN']),
#  ('including', [1134, 'VBG']),
#  ('circuit', [1133, 'NN']),
#  ('operation', [1126, 'NN']),
#  ('node', [1109, 'JJ']),
#  ('database', [1106, 'NN']),
#  ('address', [1093, 'RB']),
#  ('product', [1091, 'NN']),
#  ('determining', [1086, 'VBG']),
#  ('used', [1072, 'VBN']),
#  ('client', [1064, 'NN']),
#  ('execution', [1043, 'VBP']),
#  ('software', [1035, 'NN']),
#  ('target', [1032, 'NN']),
#  ('resource', [1025, 'NN']),
#  ('state', [1021, 'NN']),
#  ('receiving', [1019, 'VBG']),
#  ('also', [985, 'RB']),
#  ('input', [982, 'NN']),
#  ('instruction', [981, 'NN']),
#  ('source', [978, 'NN']),
#  ('comprises', [959, 'VBZ']),
#  ('received', [954, 'VBD']),
#  ('structure', [951, 'NN']),
#  ('model', [949, 'VBP']),
#  ('number', [908, 'NN']),
#  ('corresponding', [907, 'JJ']),
#  ('content', [902, 'NN']),
#  ('stored', [894, 'VBD']),
#  ('computing', [890, 'VBG']),
#  ('power', [883, 'NN']),
#  ('interface', [881, 'NN']),
#  ('design', [874, 'NN']),
#  ('embodiment', [868, 'JJ']),
#  ('present', [866, 'JJ']),
#  ('signal', [845, 'JJ']),
#  ('disclosed', [844, 'VBN']),
#  ('component', [836, 'JJ']),
#  ('multiple', [831, 'NN']),
#  ('test', [816, 'NN']),
#  ('event', [816, 'NN']),
#  ('configured', [807, 'VBD']),
#  ('determined', [802, 'VBD']),
#  ('query', [801, 'RB']),
#  ('whether', [799, 'IN']),
#  ('document', [793, 'NN']),
#  ('module', [785, 'NN']),
#  ('environment', [774, 'NN']),
#  ('image', [769, 'NN']),
#  ('devices', [765, 'NNS']),
#  ('management', [764, 'NN']),
#  ('communication', [762, 'NN']),
#  ('identified', [752, 'VBN']),
#  ('generated', [741, 'JJ']),
#  ('logic', [730, 'NN']),
#  ('embodiments', [729, 'NNS']),
#  ('element', [724, 'NN']),
#  ('nodes', [723, 'NNS']),
#  ('current', [723, 'JJ']),
#  ('providing', [705, 'VBG']),
#  ('table', [700, 'JJ']),
#  ('location', [692, 'NN']),
#  ('configuration', [691, 'NN']),
#  ('performance', [688, 'NN']),
#  ('portion', [686, 'NN']),
#  ('systems', [685, 'NNS']),
#  ('output', [685, 'NN']),
#  ('upon', [685, 'IN']),
#  ('new', [684, 'JJ']),
#  ('web', [683, 'JJ']),
#  ('comprising', [669, 'VBG']),
#  ('level', [657, 'VBP']),
#  ('elements', [654, 'NNS']),
#  ('operating', [651, 'VBG']),
#  ('group', [648, 'NN']),
#  ('provides', [645, 'VBZ']),
#  ('values', [641, 'NNS']),
#  ('list', [640, 'JJ']),
#  ('generating', [638, 'VBG']),
#  ('objects', [636, 'VBZ']),
#  ('logical', [636, 'JJ']),
#  ('instructions', [635, 'NNS']),
#  ('methods', [625, 'NNS']),
#  ('provide', [617, 'VBP']),
#  ('determine', [608, 'JJ']),
#  ('different', [604, 'JJ']),
#  ('identifying', [593, 'VBG']),
#  ('controller', [590, 'NN']),
#  ('function', [580, 'NN']),
#  ('resources', [569, 'NNS']),
#  ('array', [562, 'NN']),
#  ('according', [561, 'VBG']),
#  ('electronic', [559, 'JJ']),
#  ('two', [557, 'CD']),
#  ('thread', [555, 'NN']),
#  ('use', [553, 'NN']),
#  ('voltage', [545, 'NN']),
#  ('line', [545, 'NN']),
#  ('said', [544, 'VBD']),
#  ('page', [538, 'NN']),
#  ('components', [538, 'NNS']),
#  ('type', [531, 'NN']),
#  ('search', [531, 'NN']),
#  ('threshold', [527, 'JJ']),
#  ('pattern', [522, 'NN']),
#  ('physical', [520, 'JJ']),
#  ('layer', [520, 'NN']),
#  ('command', [520, 'NN']),
#  ('performed', [514, 'NN']),
#  ('operations', [506, 'NNS']),
#  ('order', [502, 'NN']),
#  ('particular', [497, 'JJ']),
#  ('integrated', [496, 'JJ']),
#  ('transaction', [495, 'NN']),
#  ('result', [495, 'NN']),
#  ('display', [495, 'NN']),
#  ('store', [494, 'NN']),
#  ('path', [493, 'NN']),
#  ('read', [492, 'VBP']),
#  ('tag', [488, 'NN']),
#  ('mechanism', [488, 'NN']),
#  ('performing', [487, 'VBG']),
#  ('host', [482, 'NN']),
#  ('local', [482, 'JJ']),
#  ('block', [481, 'NN']),
#  ('machine', [481, 'NN']),
#  ('key', [477, 'NN']),
#  ('point', [475, 'NN']),
#  ('error', [470, 'NN']),
#  ('requests', [464, 'NNS']),
#  ('hardware', [464, 'NN']),
#  ('automatically', [460, 'RB']),
#  ('storing', [457, 'VBG']),
#  ('medium', [454, 'NN']),
#  ('identifier', [453, 'NN']),
#  ('via', [449, 'IN']),
#  ('partition', [445, 'NN']),
#  ('results', [444, 'NNS']),
#  ('mode', [442, 'NN']),
#  ('area', [437, 'NN']),
#  ('another', [435, 'DT']),
#  ('analysis', [427, 'NN']),
#  ('coupled', [425, 'VBD']),
#  ('media', [421, 'NNS']),
#  ('write', [420, 'JJ']),
#  ('predetermined', [419, 'VBD']),
#  ('entity', [419, 'NN']),
#  ('entry', [419, 'NN']),
#  ('shared', [418, 'VBN']),
#  ('reference', [417, 'NN']),
#  ('business', [414, 'NN']),
#  ('executing', [414, 'NN']),
#  ('engine', [410, 'NN']),
#  ('made', [409, 'VBN']),
#  ('task', [408, 'NN']),
#  ('determination', [407, 'NN']),
#  ('sequence', [407, 'NN']),
#  ('implemented', [406, 'VBN']),
#  ('load', [402, 'NN']),
#  ('register', [401, 'NN']),
#  ('record', [397, 'NN']),
#  ('receives', [395, 'NNS']),
#  ('given', [394, 'VBN']),
#  ('session', [392, 'NN']),
#  ('change', [391, 'NN']),
#  ('parameters', [387, 'NNS']),
#  ('specified', [383, 'JJ']),
#  ('monitoring', [380, 'NN']),
#  ('index', [379, 'NN']),
#  ('messages', [378, 'NNS']),
#  ('available', [378, 'JJ']),
#  ('field', [377, 'NN']),
#  ('buffer', [377, 'NN']),
#  ('defined', [376, 'VBD']),
#  ('email', [375, 'VBP']),
#  ('clock', [375, 'NN']),
#  ('single', [373, 'JJ']),
#  ('remote', [373, 'JJ']),
#  ('space', [371, 'NN']),
#  ('connected', [371, 'VBN']),
#  ('stream', [369, 'NN']),
#  ('queue', [364, 'NN']),
#  ('form', [363, 'VBP']),
#  ('without', [361, 'IN']),
#  ('respective', [359, 'JJ']),
#  ('users', [359, 'NNS']),
#  ('creating', [358, 'VBG']),
#  ('detecting', [357, 'VBG']),
#  ('determines', [357, 'NNS']),
#  ('generate', [355, 'NN']),
#  ('language', [355, 'NN']),
#  ('executed', [354, 'VBN']),
#  ('security', [354, 'NN']),
#  ('responsive', [353, 'JJ']),
#  ('manager', [352, 'NN']),
#  ('metadata', [351, 'NNS']),
#  ('identify', [346, 'VBP']),
#  ('connection', [346, 'NN']),
#  ('policy', [345, 'NN']),
#  ('item', [344, 'NN']),
#  ('dynamic', [342, 'JJ']),
#  ('managing', [341, 'VBG']),
#  ('status', [341, 'NN']),
#  ('related', [340, 'VBN']),
#  ('log', [339, 'NN']),
#  ('action', [339, 'NN']),
#  ('communications', [337, 'NNS']),
#  ('digital', [333, 'JJ']),
#  ('bit', [333, 'VB']),
#  ('selection', [332, 'JJ']),
#  ('steps', [331, 'NNS']),
#  ('additional', [331, 'JJ']),
#  ('rules', [331, 'NNS']),
#  ('text', [330, 'JJ']),
#  ('tape', [330, 'NN']),
#  ('specific', [329, 'JJ']),
#  ('events', [327, 'NNS']),
#  ('region', [326, 'NN']),
#  ('selecting', [325, 'VBG']),
#  ('techniques', [325, 'NNS']),
#  ('chip', [325, 'NN']),
#  ('bus', [324, 'NN']),
#  ('profile', [323, 'NN']),
#  ('distributed', [323, 'VBN']),
#  ('attributes', [321, 'VBZ']),
#  ('third', [319, 'JJ']),
#  ('mapping', [317, 'VBG']),
#  ('applications', [314, 'NNS']),
#  ('size', [314, 'NN']),
#  ('dynamically', [313, 'RB']),
#  ('channel', [312, 'NN']),
#  ('example', [308, 'NN']),
#  ('created', [308, 'VBD']),
#  ('magnetic', [308, 'JJ']),
#  ('avatar', [307, 'NN']),
#  ('perform', [306, 'NN']),
#  ('generates', [306, 'NNS']),
#  ('rule', [305, 'NN']),
#  ('sent', [302, 'VBD']),
#  ('assigned', [301, 'VBN']),
#  ('items', [301, 'NNS']),
#  ('servers', [301, 'NNS']),
#  ('files', [300, 'NNS']),
#  ('context', [299, 'JJ']),
#  ('receive', [297, 'NN']),
#  ('accordance', [293, 'NN']),
#  ('messaging', [293, 'VBG']),
#  ('allows', [293, 'NNS']),
#  ('instance', [291, 'NN']),
#  ('modified', [290, 'VBN']),
#  ('end', [290, 'NN']),
#  ('condition', [290, 'NN']),
#  ('call', [289, 'VB']),
#  ('units', [289, 'NNS']),
#  ('frequency', [286, 'NN']),
#  ('services', [285, 'NNS']),
#  ('representation', [284, 'NN']),
#  ('part', [283, 'NN']),
#  ('tree', [283, 'JJ']),
#  ('period', [283, 'NN']),
#  ('position', [281, 'NN']),
#  ('changes', [280, 'NNS']),
#  ('primary', [278, 'JJ']),
#  ('blocks', [275, 'NNS']),
#  ('priority', [275, 'NN']),
#  ('applied', [274, 'JJ']),
#  ('identification', [274, 'NN']),
#  ('obtained', [274, 'VBN']),
#  ('protocol', [272, 'NN']),
#  ('cell', [271, 'NN']),
#  ('copy', [270, 'NN']),
#  ('records', [268, 'NNS']),
#  ('flow', [267, 'JJ']),
#  ('initial', [265, 'JJ']),
#  ('among', [264, 'IN']),
#  ('rfid', [264, 'NN']),
#  ('parameter', [264, 'NN']),
#  ('required', [262, 'VBN']),
#  ('supply', [260, 'RB']),
#  ('displayed', [259, 'VBD']),
#  ('high', [259, 'JJ']),
#  ('presented', [256, 'JJ']),
#  ('detected', [254, 'VBN']),
#  ('sets', [253, 'NNS']),
#  ('destination', [253, 'NN']),
#  ('common', [251, 'JJ']),
#  ('view', [250, 'NN']),
#  ('detection', [249, 'NN']),
#  ('universe', [248, 'JJ']),
#  ('usage', [248, 'JJ']),
#  ('window', [248, 'NN']),
#  ('attribute', [247, 'JJ']),
#  ('parallel', [247, 'JJ']),
#  ('cluster', [247, 'NN']),
#  ('link', [246, 'NN']),
#  ('active', [246, 'JJ']),
#  ('domain', [246, 'NN']),
#  ('segment', [245, 'NN']),
#  ('compute', [244, 'NN']),
#  ('processed', [243, 'VBN']),
#  ('indicating', [243, 'NN']),
#  ('original', [243, 'JJ']),
#  ('signals', [242, 'NNS']),
#  ('surface', [242, 'VBP']),
#  ('failure', [242, 'VBP']),
#  ('adapter', [242, 'NN']),
#  ('class', [241, 'NN']),
#  ('unique', [239, 'JJ']),
#  ('threads', [239, 'NNS']),
#  ('subset', [238, 'VBN']),
#  ('update', [238, 'JJ']),
#  ('next', [237, 'JJ']),
#  ('amount', [237, 'NN']),
#  ('graphical', [235, 'JJ']),
#  ('representing', [235, 'VBG']),
#  ('existing', [235, 'VBG']),
#  ('sensor', [235, 'NN']),
#  ('testing', [235, 'VBG']),
#  ('documents', [233, 'NNS']),
#  ('step', [232, 'NN']),
#  ('products', [231, 'NNS']),
#  ('packet', [231, 'NN']),
#  ('processes', [230, 'VBZ']),
#  ('video', [229, 'NN']),
#  ('disk', [229, 'NN']),
#  ('template', [229, 'JJ']),
#  ('name', [229, 'NN']),
#  ('section', [228, 'NN']),
#  ('containing', [227, 'VBG']),
#  ('functions', [227, 'NNS']),
#  ('across', [227, 'IN']),
#  ('patterns', [227, 'NNS']),
#  ('external', [226, 'NN']),
#  ('characteristics', [225, 'NNS']),
#  ('processors', [225, 'NNS']),
#  ('counter', [223, 'NN']),
#  ('sending', [223, 'VBG']),
#  ('job', [223, 'NN']),
#  ('tool', [222, 'NN']),
#  ('collection', [222, 'NN']),
#  ('solution', [222, 'NN']),
#  ('format', [221, 'JJ']),
#  ('graph', [220, 'NN']),
#  ('partitions', [220, 'NNS']),
#  ('range', [219, 'NN']),
#  ('core', [219, 'NN']),
#  ('base', [219, 'NN']),
#  ('generation', [219, 'NN']),
#  ('stores', [219, 'NNS']),
#  ('included', [218, 'VBD']),
#  ('individual', [217, 'JJ']),
#  ('identifies', [217, 'NNS']),
#  ('rate', [216, 'NN']),
#  ('running', [216, 'VBG']),
#  ('tags', [216, 'VBP']),
#  ('temperature', [215, 'NN']),
#  ('respect', [214, 'NN']),
#  ('directory', [213, 'NN']),
#  ('uses', [213, 'VBZ']),
#  ('branch', [212, 'NN']),
#  ('defining', [211, 'VBG']),
#  ('verification', [211, 'NN']),
#  ('comparing', [211, 'VBG']),
#  ('grid', [210, 'JJ']),
#  ('world', [210, 'NN']),
#  ('updated', [210, 'VBD']),
#  ('locations', [210, 'NNS']),
#  ('readable', [210, 'JJ']),
#  ('repository', [210, 'VBP']),
#  ('version', [209, 'NN']),
#  ('controlling', [209, 'VBG']),
#  ('located', [208, 'VBN']),
#  ('delay', [207, 'NN']),
#  ('activity', [207, 'NN']),
#  ('pipeline', [206, 'NN']),
#  ('lines', [206, 'NNS']),
#  ('work', [205, 'NN']),
#  ('monitor', [205, 'NN']),
#  ('displaying', [204, 'VBG']),
#  ('matching', [204, 'NN']),
#  ('entries', [204, 'NNS']),
#  ('variable', [204, 'JJ']),
#  ('select', [203, 'NN']),
#  ('timing', [200, 'VBG']),
#  ('count', [200, 'NN']),
#  ('paths', [199, 'NNS']),
#  ('structures', [197, 'NNS']),
#  ('requested', [197, 'VBN']),
#  ('thereby', [197, 'RB']),
#  ('portions', [197, 'NNS']),
#  ('optical', [196, 'JJ']),
#  ('subsequent', [196, 'JJ']),
#  ('total', [196, 'JJ']),
#  ('means', [195, 'VBZ']),
#  ('algorithm', [195, 'JJ']),
#  ('mask', [195, 'NN']),
#  ('distribution', [194, 'NN']),
#  ('compared', [193, 'VBN']),
#  ('plan', [193, 'NN']),
#  ('candidate', [192, 'NN']),
#  ('desired', [192, 'VBN']),
#  ('port', [192, 'NN']),
#  ('manner', [191, 'NN']),
#  ('create', [190, 'NN']),
#  ('servo', [190, 'JJ']),
#  ('word', [190, 'NN']),
#  ('real', [189, 'JJ']),
#  ('vehicle', [189, 'NN']),
#  ('provider', [189, 'NN']),
#  ('scan', [188, 'JJ']),
#  ('substrate', [188, 'NN']),
#  ('types', [188, 'NNS']),
#  ('addresses', [188, 'NNS']),
#  ('description', [187, 'NN']),
#  ('drive', [187, 'VBP']),
#  ('frame', [187, 'NN']),
#  ('agent', [187, 'NN']),
#  ('trace', [187, 'VBP']),
#  ('proxy', [187, 'NN']),
#  ('thus', [186, 'RB']),
#  ('translation', [186, 'NN']),
#  ('comparison', [185, 'NN']),
#  ('instant', [185, 'JJ']),
#  ('entities', [185, 'NNS']),
#  ('match', [185, 'NN']),
#  ('retrieved', [185, 'VBD']),
#  ('relationship', [185, 'NN']),
#  ('consumption', [184, 'NN']),
#  ('relative', [184, 'JJ']),
#  ('potential', [184, 'JJ']),
#  ('filter', [183, 'JJ']),
#  ('addition', [183, 'NN']),
#  ('recording', [183, 'VBG']),
#  ('stage', [183, 'NN']),
#  ('history', [183, 'NN']),
#  ('cells', [183, 'NNS']),
#  ('calculated', [182, 'VBD']),
#  ('simulation', [181, 'NN']),
#  ('allocation', [181, 'NN']),
#  ('transmitted', [180, 'VBD']),
#  ('accessing', [180, 'VBG']),
#  ('random', [180, 'VBP']),
#  ('points', [179, 'NNS']),
#  ('described', [179, 'JJ']),
#  ('subsystem', [178, 'JJ']),
#  ('pair', [178, 'JJ']),
#  ('commands', [178, 'NNS']),
#  ('segments', [177, 'NNS']),
#  ('bits', [177, 'NNS']),
#  ('notification', [176, 'NN']),
#  ('implementing', [175, 'VBG']),
#  ('audio', [175, 'NN']),
#  ('site', [175, 'NN']),
#  ('problem', [175, 'NN']),
#  ('conditions', [174, 'NNS']),
#  ('indicates', [174, 'NNS']),
#  ('indicator', [173, 'NN']),
#  ('presentation', [173, 'NN']),
#  ('previously', [173, 'RB']),
#  ('requesting', [173, 'VBG']),
#  ('functional', [173, 'JJ']),
#  ('selectively', [172, 'RB']),
#  ('transformation', [172, 'NN']),
#  ('along', [171, 'IN']),
#  ('lower', [171, 'JJR']),
#  ('schema', [170, 'NN']),
#  ('library', [170, 'JJ']),
#  ('monitored', [169, 'VBD']),
#  ('customer', [169, 'NN']),
#  ('heat', [169, 'NN']),
#  ('transfer', [169, 'NN']),
#  ('xml', [168, 'JJ']),
#  ('images', [168, 'NNS']),
#  ('lock', [168, 'NN']),
#  ('feature', [168, 'NN']),
#  ('gate', [168, 'NN']),
#  ('support', [168, 'NN']),
#  ('recipient', [167, 'NN']),
#  ('tracking', [167, 'VBG']),
#  ('groups', [167, 'NNS']),
#  ('generator', [167, 'NN']),
#  ('utilizing', [167, 'VBG']),
#  ('low', [167, 'JJ']),
#  ('interest', [167, 'NN']),
#  ('tasks', [166, 'NNS']),
#  ('phase', [166, 'NN']),
#  ('actions', [166, 'NNS']),
#  ('energy', [166, 'NN']),
#  ('electrical', [165, 'JJ']),
#  ('technique', [165, 'JJ']),
#  ('authentication', [165, 'NN']),
#  ('enable', [165, 'JJ']),
#  ('applying', [164, 'VBG']),
#  ('manufacturing', [164, 'VBG']),
#  ('backup', [164, 'NN']),
#  ('programming', [164, 'VBG']),
#  ('traffic', [164, 'NN']),
#  ('global', [163, 'JJ']),
#  ('transmitting', [163, 'VBG']),
#  ('requirements', [162, 'NNS']),
#  ('secondary', [162, 'JJ']),
#  ('allow', [162, 'VBP']),
#  ('material', [162, 'NN']),
#  ('execute', [161, 'VBP']),
#  ('switch', [161, 'VB']),
#  ('criteria', [161, 'NNS']),
#  ('reading', [161, 'VBG']),
#  ('hierarchical', [161, 'JJ']),
#  ('written', [161, 'VBN']),
#  ('map', [160, 'NN']),
#  ('tables', [160, 'NNS']),
#  ('semiconductor', [160, 'NN']),
#  ('accessed', [160, 'VBD']),
#  ('adapted', [159, 'VBD']),
#  ('regions', [159, 'NNS']),
#  ('actual', [158, 'JJ']),
#  ('definition', [158, 'NN']),
#  ('card', [158, 'NN']),
#  ('enables', [158, 'NNS']),
#  ('aspect', [158, 'JJ']),
#  ('article', [157, 'NN']),
#  ('routing', [157, 'VBG']),
#  ('n', [157, 'JJ']),
#  ('less', [156, 'CC']),
#  ('capable', [156, 'JJ']),
#  ('manufacture', [156, 'NN']),
#  ('pointer', [156, 'NN']),
#  ('models', [155, 'NNS']),
#  ('architecture', [155, 'NN']),
#  ('browser', [155, 'NN']),
#  ('updates', [155, 'NNS']),
#  ('issue', [154, 'NN']),
#  ('sends', [153, 'VBZ']),
#  ('reducing', [153, 'VBG']),
#  ('vector', [153, 'NN']),
#  ('indication', [153, 'NN']),
#  ('chat', [152, 'DT']),
#  ('directed', [152, 'VBD']),
#  ('signature', [152, 'NN']),
#  ('maintaining', [152, 'VBG']),
#  ('circuitry', [152, 'NN']),
#  ('series', [152, 'NN']),
#  ('comprise', [152, 'NN']),
#  ('volume', [152, 'NN']),
#  ('various', [151, 'JJ']),
#  ('levels', [150, 'NNS']),
#  ('composite', [150, 'NN']),
#  ('automated', [150, 'VBD']),
#  ('prior', [150, 'JJ']),
#  ('enterprise', [149, 'NN']),
#  ('pool', [149, 'NN']),
#  ('screen', [149, 'NN']),
#  ('controlled', [149, 'VBD']),
#  ('optimization', [148, 'NN']),
#  ('analyzing', [148, 'VBG']),
#  ('setting', [148, 'VBG']),
#  ('recovery', [148, 'NN']),
#  ('platform', [148, 'NN']),
#  ('predefined', [148, 'VBN']),
#  ('fields', [147, 'NNS']),
#  ('exemplary', [147, 'JJ']),
#  ('length', [147, 'VBP']),
#  ('performs', [147, 'NNS']),
#  ('combination', [146, 'NN']),
#  ('cost', [146, 'NN']),
#  ('static', [146, 'JJ']),
#  ('cycle', [146, 'NN']),
#  ('previous', [146, 'JJ']),
#  ('contains', [146, 'NNS']),
#  ('handling', [146, 'VBG']),
#  ('relates', [145, 'VBZ']),
#  ('hierarchy', [145, 'JJ']),
#  ('master', [145, 'VBP']),
#  ('queries', [145, 'NNS']),
#  ('either', [144, 'CC']),
#  ('driver', [144, 'NN']),
#  ('transmission', [143, 'NN']),
#  ('possible', [143, 'JJ']),
#  ('contents', [143, 'NNS']),
#  ('recorded', [142, 'VBD']),
#  ('character', [142, 'NN']),
#  ('resolution', [141, 'NN']),
#  ('keys', [141, 'NNS']),
#  ('registers', [141, 'NNS']),
#  ('association', [141, 'NN']),
#  ('valid', [141, 'JJ']),
#  ('added', [140, 'JJ']),
#  ('visual', [140, 'JJ']),
#  ('contact', [140, 'NN']),
#  ('calculating', [140, 'VBG']),
#  ('mechanisms', [140, 'NNS']),
#  ('allocated', [139, 'VBN']),
#  ('reader', [139, 'NN']),
#  ('id', [139, 'NN']),
#  ('hash', [139, 'NN']),
#  ('classification', [139, 'NN']),
#  ('sources', [138, 'NNS']),
#  ('preferred', [138, 'JJ']),
#  ('variables', [138, 'NNS']),
#  ('analyzed', [137, 'JJ']),
#  ('behavior', [137, 'IN']),
#  ('collected', [137, 'VBN']),
#  ('inventory', [137, 'NN']),
#  ('critical', [137, 'JJ']),
#  ('implementation', [136, 'NN']),
#  ('appropriate', [136, 'JJ']),
#  ('packets', [136, 'NNS']),
#  ('greater', [136, 'JJR']),
#  ('executable', [136, 'JJ']),
#  ('sample', [136, 'NN']),
#  ('runtime', [135, 'NN']),
#  ('transactions', [135, 'NNS']),
#  ('center', [134, 'NN']),
#  ('obtaining', [134, 'VBG']),
#  ('workload', [134, 'VBP']),
#  ('detect', [133, 'JJ']),
#  ('directly', [133, 'RB']),
#  ('selects', [133, 'NNS']),
#  ('allowing', [133, 'VBG']),
#  ('corresponds', [132, 'NNS']),
#  ('errors', [132, 'NNS']),
#  ('side', [132, 'NN']),
#  ('preferably', [132, 'RB']),
#  ('color', [131, 'NN']),
#  ('switching', [131, 'VBG']),
#  ('following', [131, 'VBG']),
#  ('mobile', [131, 'VBP']),
#  ('relationships', [131, 'NNS']),
#  ('basis', [131, 'NN']),
#  ('capacity', [130, 'NN']),
#  ('instances', [130, 'NNS']),
#  ('updating', [130, 'VBG']),
#  ('head', [130, 'NN']),
#  ('associating', [130, 'VBG']),
#  ('column', [130, 'NN']),
#  ('changed', [129, 'VBD']),
#  ('inputs', [129, 'NNS']),
#  ('subject', [129, 'JJ']),
#  ('dependence', [129, 'NN']),
#  ('direct', [128, 'JJ']),
#  ('receiver', [128, 'RB']),
#  ('pages', [128, 'NNS']),
#  ('portable', [128, 'JJ']),
#  ('layout', [128, 'RB']),
#  ('annotation', [128, 'VBP']),
#  ('ic', [128, 'NN']),
#  ('features', [127, 'NNS']),
#  ('maximum', [127, 'NN']),
#  ('interaction', [127, 'NN']),
#  ('reduced', [127, 'VBN']),
#  ('retrieving', [127, 'NN']),
#  ('resulting', [127, 'VBG']),
#  ('row', [127, 'VBP']),
#  ('relevant', [126, 'JJ']),
#  ('extracted', [126, 'JJ']),
#  ('speed', [126, 'NN']),
#  ('difference', [126, 'NN']),
#  ('programs', [125, 'NNS']),
#  ('operand', [125, 'VBP']),
#  ('placement', [125, 'NN']),
#  ('run', [125, 'VBP']),
#  ('gui', [125, 'JJ']),
#  ('well', [124, 'RB']),
#  ('member', [123, 'NN']),
#  ('identity', [123, 'NN']),
#  ('string', [123, 'VBG']),
#  ('known', [123, 'VBN']),
#  ('quality', [123, 'NN']),
#  ('knowledge', [122, 'NN']),
#  ('operational', [122, 'JJ']),
#  ('formed', [122, 'VBD']),
#  ('independent', [122, 'JJ']),
#  ('separate', [122, 'JJ']),
#  ('additionally', [122, 'RB']),
#  ('distance', [122, 'NN']),
#  ('optimal', [122, 'JJ']),
#  ('forming', [122, 'VBG']),
#  ('reduce', [122, 'VB']),
#  ('asynchronous', [122, 'JJ']),
#  ('internal', [121, 'JJ']),
#  ('latch', [121, 'JJ']),
#  ('stack', [121, 'NN']),
#  ('enabling', [120, 'VBG']),
#  ('way', [120, 'NN']),
#  ('words', [120, 'NNS']),
#  ('central', [120, 'JJ']),
#  ('specifying', [120, 'VBG']),
#  ('matches', [120, 'NNS']),
#  ('times', [120, 'NNS']),
#  ('completion', [120, 'NN']),
#  ('computed', [120, 'VBD']),
#  ('placed', [119, 'VBD']),
#  ('presence', [119, 'NN']),
#  ('edge', [119, 'VBP']),
#  ('fixed', [118, 'VBN']),
#  ('maintained', [118, 'VBD']),
#  ('track', [118, 'JJ']),
#  ('measurement', [118, 'NN']),
#  ('utilization', [118, 'NN']),
#  ('prefetch', [118, 'NN']),
#  ('classes', [117, 'NNS']),
#  ('return', [117, 'NN']),
#  ('functionality', [117, 'NN']),
#  ('enabled', [117, 'VBD']),
#  ('direction', [117, 'NN']),
#  ('boot', [117, 'JJ']),
#  ('asset', [117, 'NN']),
#  ('modifying', [117, 'VBG']),
#  ('cohort', [116, 'NN']),
#  ('streams', [116, 'JJ']),
#  ('assigning', [116, 'VBG']),
#  ('interconnect', [116, 'JJ']),
#  ('terminal', [116, 'JJ']),
#  ('decision', [116, 'NN']),
#  ('main', [116, 'JJ']),
#  ('designated', [115, 'VBD']),
#  ('terms', [115, 'NNS']),
#  ('score', [115, 'VBP']),
#  ('loop', [115, 'NN']),
#  ('light', [114, 'JJ']),
#  ('obtain', [114, 'VB']),
#  ('writing', [114, 'VBG']),
#  ('combined', [114, 'JJ']),
#  ('general', [114, 'JJ']),
#  ('currently', [114, 'RB']),
#  ('equal', [114, 'JJ']),
#  ('transistor', [114, 'NN']),
#  ('scheduling', [114, 'NN']),
#  ('optimizing', [113, 'VBG']),
#  ('secure', [113, 'NN']),
#  ('computational', [113, 'JJ']),
#  ('term', [112, 'NN']),
#  ('constraints', [112, 'NNS']),
#  ('complete', [112, 'JJ']),
#  ('fault', [112, 'NN']),
#  ('utilized', [112, 'VBD']),
#  ('free', [112, 'JJ']),
#  ('building', [112, 'NN']),
#  ('meeting', [112, 'NN']),
#  ('disposed', [112, 'JJ']),
#  ('project', [112, 'NN']),
#  ('machines', [112, 'NNS']),
#  ('case', [112, 'NN']),
#  ('package', [111, 'NN']),
#  ('back', [111, 'RP']),
#  ('improved', [111, 'VBN']),
#  ('ip', [111, 'JJ']),
#  ('technology', [111, 'NN']),
#  ('accesses', [111, 'NNS']),
#  ('standard', [110, 'NN']),
#  ('states', [109, 'NNS']),
#  ('probe', [109, 'VBP']),
#  ('adding', [109, 'VBG']),
#  ('coverage', [109, 'NN']),
#  ('latches', [109, 'VBZ']),
#  ('modules', [108, 'NNS']),
#  ('indicate', [108, 'NN']),
#  ('managed', [108, 'VBD']),
#  ('protection', [108, 'NN']),
#  ('markup', [108, 'JJ']),
#  ('party', [107, 'NN']),
#  ('internet', [107, 'NN']),
#  ('establishing', [107, 'VBG']),
#  ('operable', [107, 'JJ']),
#  ('links', [107, 'NNS']),
#  ('able', [106, 'JJ']),
#  ('root', [106, 'NN']),
#  ('risk', [106, 'NN']),
#  ('captured', [105, 'JJ']),
#  ('specification', [105, 'NN']),
#  ('usable', [105, 'JJ']),
#  ('efficient', [105, 'JJ']),
#  ('expected', [105, 'VBN']),
#  ('returned', [105, 'VBD']),
#  ('describing', [104, 'VBG']),
#  ('password', [104, 'NN']),
#  ('rendering', [104, 'VBG']),
#  ('dependent', [104, 'JJ']),
#  ('metrics', [104, 'NNS']),
#  ('statistical', [103, 'JJ']),
#  ('checking', [103, 'NN']),
#  ('chain', [103, 'NN']),
#  ('recipients', [103, 'NNS']),
#  ('approach', [103, 'RB']),
#  ('measured', [103, 'VBD']),
#  ('fabric', [103, 'NN']),
#  ('semantic', [103, 'JJ']),
#  ('infrastructure', [103, 'NN']),
#  ('authorization', [102, 'NN']),
#  ('relating', [102, 'VBG']),
#  ('minimum', [102, 'JJ']),
#  ('modification', [102, 'NN']),
#  ('together', [102, 'RB']),
#  ('established', [102, 'VBN']),
#  ('prediction', [102, 'NN']),
#  ('metric', [102, 'JJ']),
#  ('voice', [102, 'NN']),
#  ('large', [101, 'JJ']),
#  ('availability', [101, 'NN']),
#  ('development', [101, 'NN']),
#  ('structured', [101, 'VBD']),
#  ('executes', [100, 'NNS']),
#  ('noise', [100, 'NN']),
#  ('occurs', [100, 'VBZ']),
#  ('completed', [100, 'VBN']),
#  ('compiler', [100, 'JJ']),
#  ('enhanced', [100, 'VBD']),
#  ('starting', [100, 'VBG']),
#  ('automatic', [99, 'JJ']),
#  ('estimated', [99, 'VBN']),
#  ('attached', [99, 'VBD']),
#  ('higher', [99, 'JJR']),
#  ('boundary', [99, 'JJ']),
#  ('removed', [99, 'VBN']),
#  ('consumer', [99, 'NN']),
#  ('embedded', [98, 'VBD']),
#  ('shape', [98, 'NN']),
#  ('intermediate', [98, 'JJ']),
#  ('outputs', [98, 'VBP']),
#  ('thermal', [98, 'JJ']),
#  ('illustrative', [98, 'JJ']),
#  ('configuring', [97, 'VBG']),
#  ('framework', [97, 'NN']),
#  ('assembly', [97, 'NN']),
#  ('accessible', [97, 'JJ']),
#  ('substantially', [97, 'RB']),
#  ('feedback', [97, 'NN']),
#  ('respectively', [97, 'RB']),
#  ('facility', [97, 'NN']),
#  ('factor', [97, 'NN']),
#  ('encrypted', [97, 'VBD']),
#  ('handler', [97, 'NN']),
#  ('mapped', [96, 'VBD']),
#  ('circuits', [96, 'NNS']),
#  ('clients', [96, 'NNS']),
#  ('buffers', [96, 'NNS']),
#  ('improve', [96, 'VB']),
#  ('interval', [96, 'JJ']),
#  ('sensors', [96, 'NNS']),
#  ('extracting', [95, 'VBG']),
#  ('evaluation', [95, 'NN']),
#  ('certain', [95, 'JJ']),
#  ('arranged', [95, 'VBD']),
#  ('changing', [95, 'VBG']),
#  ('account', [95, 'NN']),
#  ('needed', [95, 'JJ']),
#  ('identifiers', [95, 'NNS']),
#  ('onto', [95, 'IN']),
#  ('references', [95, 'NNS']),
#  ('collaborative', [95, 'JJ']),
#  ('modeling', [95, 'VBG']),
#  ('dependency', [95, 'NN']),
#  ('special', [94, 'JJ']),
#  ('moving', [94, 'VBG']),
#  ('adjacent', [94, 'JJ']),
#  ('cores', [94, 'NNS']),
#  ('regarding', [94, 'VBG']),
#  ('child', [94, 'NN']),
#  ('interrupt', [94, 'VBP']),
#  ('volumes', [94, 'NNS']),
#  ('1', [93, 'CD']),
#  ('token', [93, 'VBN']),
#  ('defines', [93, 'NNS']),
#  ('detects', [93, 'NNS']),
#  ('air', [93, 'NN']),
#  ('print', [93, 'NN']),
#  ('computers', [93, 'NNS']),
#  ('scanning', [93, 'VBG']),
#  ('exceeds', [93, 'NNS']),
#  ('measuring', [93, 'VBG']),
#  ('statistics', [93, 'NNS']),
#  ('delivery', [92, 'NN']),
#  ('floating', [92, 'VBG']),
#  ('need', [92, 'MD']),
#  ('pixel', [92, 'JJ']),
#  ('sharing', [92, 'VBG']),
#  ('optimized', [92, 'VBD']),
#  ('characteristic', [92, 'JJ']),
#  ('expression', [91, 'NN']),
#  ('constraint', [91, 'NN']),
#  ('searching', [91, 'VBG']),
#  ('limit', [91, 'NN']),
#  ('adjusted', [91, 'VBN']),
#  ('effective', [91, 'JJ']),
#  ('occurrence', [91, 'NN']),
#  ('matrix', [91, 'RBS']),
#  ('category', [90, 'JJ']),
#  ('members', [90, 'NNS']),
#  ('activities', [90, 'NNS']),
#  ('pulse', [90, 'JJ']),
#  ('final', [90, 'JJ']),
#  ('sender', [90, 'RBR']),
#  ('alert', [90, 'VBP']),
#  ('bandwidth', [90, 'NN']),
#  ('migration', [90, 'NN']),
#  ('snoop', [90, 'NN']),
#  ('fetch', [90, 'NN']),
#  ('abstract', [90, 'JJ']),
#  ('specifically', [89, 'RB']),
#  ('encoded', [89, 'VBN']),
#  ('cpu', [89, 'VBP']),
#  ('check', [89, 'VBP']),
#  ('specifies', [89, 'NNS']),
#  ('particularly', [89, 'RB']),
#  ('properties', [89, 'NNS']),
#  ('generally', [89, 'RB']),
#  ('wiring', [89, 'VBG']),
#  ('creation', [88, 'NN']),
#  ('zero', [88, 'CD']),
#  ('latency', [88, 'NN']),
#  ('top', [88, 'JJ']),
#  ('chips', [88, 'NNS']),
#  ('manage', [88, 'VBP']),
#  ('thereof', [88, 'IN']),
#  ('produce', [87, 'NN']),
#  ('start', [87, 'VB']),
#  ('overall', [87, 'JJ']),
#  ('representative', [87, 'JJ']),
#  ('loaded', [87, 'VBN']),
#  ('replacement', [87, 'NN']),
#  ('slot', [87, 'NN']),
#  ('passing', [87, 'VBG']),
#  ('similar', [86, 'JJ']),
#  ('complex', [86, 'JJ']),
#  ('incoming', [86, 'VBG']),
#  ('communicating', [86, 'VBG']),
#  ('clusters', [86, 'NNS']),
#  ('measure', [86, 'NN']),
#  ('weight', [86, 'VBD']),
#  ('b', [86, 'NN']),
#  ('routine', [86, 'JJ']),
#  ('communicate', [86, 'NN']),
#  ('operates', [86, 'VBZ']),
#  ('station', [86, 'NN']),
#  ('domains', [86, 'NNS']),
#  ('simultaneously', [86, 'RB']),
#  ('property', [86, 'NN']),
#  ('policies', [85, 'NNS']),
#  ('scheme', [85, 'NN']),
#  ('efficiency', [85, 'NN']),
#  ('future', [85, 'JJ']),
#  ('exists', [85, 'VBZ']),
#  ('programmable', [85, 'JJ']),
#  ('columns', [85, 'JJ']),
#  ('private', [85, 'JJ']),
#  ('sequential', [85, 'JJ']),
#  ('occur', [85, 'VBP']),
#  ('operate', [85, 'NN']),
#  ('avatars', [84, 'VBZ']),
#  ('represent', [84, 'NN']),
#  ('portal', [84, 'JJ']),
#  ('navigation', [84, 'NN']),
#  ('contained', [84, 'VBD']),
#  ...]

# %%
df_by_2index(pat08, dir08, top10[0], ipcs[0])
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 65556       65556          1620
# 98325       98325          9200
# 28             28            28
# 29             29            29
# 98334       98334          9209
# 30             30            30
# 35             35            35
# 65580       65580          1644
# 49             49            49
# 50             50            50
# 51             51            51
# 65586       65586          1650
# 53             53            53
# 54             54            54
# 56             56            56
# 58             58            58
# 64             64            64
# 65             65            65
# 66             66            66
# 65600       65600          1664
# 98370       98370          9245
# 70             70            70
# 98380       98380          9255
# 84             84            84
# 65624       65624          1688
# 93             93            93
# 98399       98399          9274
# 96             96            96
# 99             99            99
# 100           100           100
# ...           ...           ...
# 65257       65257          1321
# 65260       65260          1324
# 98037       98037          8912
# 98038       98038          8913
# 65273       65273          1337
# 65274       65274          1338
# 98041       98041          8916
# 65278       65278          1342
# 65284       65284          1348
# 65286       65286          1350
# 65287       65287          1351
# 65306       65306          1370
# 65307       65307          1371
# 65312       65312          1376
# 98096       98096          8971
# 98100       98100          8975
# 65336       65336          1400
# 65345       65345          1409
# 65360       65360          1424
# 65401       65401          1465
# 65402       65402          1466
# 65423       65423          1487
# 65424       65424          1488
# 98199       98199          9074
# 65448       65448          1512
# 65485       65485          1549
# 98256       98256          9131
# 98258       98258          9133
# 65500       65500          1564
# 65535       65535          1599
#
#                                                     IPCs  \
# 65556  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 98325  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 28     [{u'ipc_section': u'G', u'ipc_subclass': u'N',...
# 29     [{u'ipc_section': u'G', u'ipc_subclass': u'Q',...
# 98334  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 30     [{u'ipc_section': u'G', u'ipc_subclass': u'Q',...
# 35     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65580  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 49     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 50     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 51     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65586  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 53     [{u'ipc_section': u'G', u'ipc_subclass': u'K',...
# 54     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 56     [{u'ipc_section': u'G', u'ipc_subclass': u'B',...
# 58     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 64     [{u'ipc_section': u'G', u'ipc_subclass': u'K',...
# 65     [{u'ipc_section': u'G', u'ipc_subclass': u'B',...
# 66     [{u'ipc_section': u'G', u'ipc_subclass': u'B',...
# 65600  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 98370  [{u'ipc_section': u'G', u'ipc_subclass': u'G',...
# 70     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 98380  [{u'ipc_section': u'H', u'ipc_subclass': u'M',...
# 84     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65624  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 93     [{u'ipc_section': u'G', u'ipc_subclass': u'G',...
# 98399  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 96     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 99     [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 100    [{u'ipc_section': u'H', u'ipc_subclass': u'N',...
# ...                                                  ...
# 65257  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65260  [{u'ipc_section': u'H', u'ipc_subclass': u'M',...
# 98037  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 98038  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65273  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65274  [{u'ipc_section': u'G', u'ipc_subclass': u'L',...
# 98041  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65278  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65284  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65286  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65287  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65306  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65307  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65312  [{u'ipc_section': u'H', u'ipc_subclass': u'M',...
# 98096  [{u'ipc_section': u'H', u'ipc_subclass': u'N',...
# 98100  [{u'ipc_section': u'G', u'ipc_subclass': u'C',...
# 65336  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65345  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65360  [{u'ipc_section': u'G', u'ipc_subclass': u'T',...
# 65401  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65402  [{u'ipc_section': u'H', u'ipc_subclass': u'L',...
# 65423  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65424  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 98199  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65448  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65485  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 98256  [{u'ipc_section': u'G', u'ipc_subclass': u'Q',...
# 98258  [{u'ipc_section': u'G', u'ipc_subclass': u'Q',...
# 65500  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
# 65535  [{u'ipc_section': u'G', u'ipc_subclass': u'F',...
#
#                                           applications  \
# 65556  [{u'app_type': u'12', u'app_id': u'12/189594'}]
# 98325  [{u'app_type': u'12', u'app_id': u'12/343021'}]
# 28     [{u'app_type': u'12', u'app_id': u'12/042434'}]
# 29     [{u'app_type': u'12', u'app_id': u'12/019004'}]
# 98334  [{u'app_type': u'12', u'app_id': u'12/334088'}]
# 30     [{u'app_type': u'12', u'app_id': u'12/103472'}]
# 35     [{u'app_type': u'12', u'app_id': u'12/039690'}]
# 65580  [{u'app_type': u'12', u'app_id': u'12/181908'}]
# 49     [{u'app_type': u'12', u'app_id': u'12/027015'}]
# 50     [{u'app_type': u'11', u'app_id': u'11/969413'}]
# 51     [{u'app_type': u'12', u'app_id': u'12/045406'}]
# 65586  [{u'app_type': u'12', u'app_id': u'12/127298'}]
# 53     [{u'app_type': u'11', u'app_id': u'11/971376'}]
# 54     [{u'app_type': u'11', u'app_id': u'11/970092'}]
# 56     [{u'app_type': u'12', u'app_id': u'12/017791'}]
# 58     [{u'app_type': u'11', u'app_id': u'11/117749'}]
# 64     [{u'app_type': u'11', u'app_id': u'11/970946'}]
# 65     [{u'app_type': u'12', u'app_id': u'12/041265'}]
# 66     [{u'app_type': u'12', u'app_id': u'12/020716'}]
# 65600  [{u'app_type': u'12', u'app_id': u'12/201793'}]
# 98370  [{u'app_type': u'12', u'app_id': u'12/333273'}]
# 70     [{u'app_type': u'12', u'app_id': u'12/033668'}]
# 98380  [{u'app_type': u'12', u'app_id': u'12/257037'}]
# 84     [{u'app_type': u'12', u'app_id': u'12/109321'}]
# 65624  [{u'app_type': u'12', u'app_id': u'12/169919'}]
# 93     [{u'app_type': u'12', u'app_id': u'12/059698'}]
# 98399  [{u'app_type': u'12', u'app_id': u'12/324829'}]
# 96     [{u'app_type': u'12', u'app_id': u'12/020543'}]
# 99     [{u'app_type': u'12', u'app_id': u'12/060163'}]
# 100    [{u'app_type': u'12', u'app_id': u'12/054145'}]
# ...                                                ...
# 65257  [{u'app_type': u'12', u'app_id': u'12/187522'}]
# 65260  [{u'app_type': u'12', u'app_id': u'12/126802'}]
# 98037  [{u'app_type': u'12', u'app_id': u'12/251507'}]
# 98038  [{u'app_type': u'12', u'app_id': u'12/342424'}]
# 65273  [{u'app_type': u'12', u'app_id': u'12/122171'}]
# 65274  [{u'app_type': u'12', u'app_id': u'12/130934'}]
# 98041  [{u'app_type': u'12', u'app_id': u'12/268881'}]
# 65278  [{u'app_type': u'12', u'app_id': u'12/140053'}]
# 65284  [{u'app_type': u'12', u'app_id': u'12/177450'}]
# 65286  [{u'app_type': u'12', u'app_id': u'12/165931'}]
# 65287  [{u'app_type': u'12', u'app_id': u'12/146119'}]
# 65306  [{u'app_type': u'12', u'app_id': u'12/137166'}]
# 65307  [{u'app_type': u'12', u'app_id': u'12/170504'}]
# 65312  [{u'app_type': u'12', u'app_id': u'12/120529'}]
# 98096  [{u'app_type': u'12', u'app_id': u'12/249728'}]
# 98100  [{u'app_type': u'12', u'app_id': u'12/346103'}]
# 65336  [{u'app_type': u'12', u'app_id': u'12/188156'}]
# 65345  [{u'app_type': u'12', u'app_id': u'12/188047'}]
# 65360  [{u'app_type': u'12', u'app_id': u'12/174985'}]
# 65401  [{u'app_type': u'12', u'app_id': u'12/128264'}]
# 65402  [{u'app_type': u'12', u'app_id': u'12/123965'}]
# 65423  [{u'app_type': u'12', u'app_id': u'12/177703'}]
# 65424  [{u'app_type': u'12', u'app_id': u'12/197819'}]
# 98199  [{u'app_type': u'12', u'app_id': u'12/241429'}]
# 65448  [{u'app_type': u'12', u'app_id': u'12/181397'}]
# 65485  [{u'app_type': u'12', u'app_id': u'12/145021'}]
# 98256  [{u'app_type': u'12', u'app_id': u'12/271301'}]
# 98258  [{u'app_type': u'12', u'app_id': u'12/276757'}]
# 65500  [{u'app_type': u'12', u'app_id': u'12/145200'}]
# 65535  [{u'app_type': u'12', u'app_id': u'12/137683'}]
#
#                                                assignees  \
# 65556  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98325  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 28     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 29     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98334  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 30     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 35     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65580  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 49     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 50     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 51     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65586  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 53     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 54     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 56     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 58     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 64     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 66     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65600  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98370  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 70     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98380  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 84     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65624  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 93     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98399  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 96     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 99     [{u'assignee_key_id': u'276821', u'assignee_ci...
# 100    [{u'assignee_key_id': u'276821', u'assignee_ci...
# ...                                                  ...
# 65257  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65260  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98037  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98038  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65273  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65274  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98041  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65278  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65284  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65286  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65287  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65306  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65307  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65312  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98096  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98100  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65336  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65345  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65360  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65401  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65402  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65423  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65424  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98199  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65448  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65485  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98256  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 98258  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65500  [{u'assignee_key_id': u'276821', u'assignee_ci...
# 65535  [{u'assignee_key_id': u'276821', u'assignee_ci...
#
#                                            cited_patents  \
# 65556  [{u'cited_patent_category': u'cited by applica...
# 98325  [{u'cited_patent_category': u'cited by applica...
# 28     [{u'cited_patent_category': u'cited by applica...
# 29     [{u'cited_patent_category': u'cited by applica...
# 98334  [{u'cited_patent_category': u'cited by applica...
# 30     [{u'cited_patent_category': u'cited by examine...
# 35     [{u'cited_patent_category': u'cited by examine...
# 65580  [{u'cited_patent_category': u'cited by examine...
# 49       [{u'cited_patent_category': u'cited by other'}]
# 50     [{u'cited_patent_category': u'cited by examine...
# 51       [{u'cited_patent_category': u'cited by other'}]
# 65586  [{u'cited_patent_category': u'cited by examine...
# 53     [{u'cited_patent_category': u'cited by other'}...
# 54     [{u'cited_patent_category': u'cited by examine...
# 56     [{u'cited_patent_category': u'cited by examine...
# 58       [{u'cited_patent_category': u'cited by other'}]
# 64                    [{u'cited_patent_category': None}]
# 65     [{u'cited_patent_category': u'cited by examine...
# 66       [{u'cited_patent_category': u'cited by other'}]
# 65600  [{u'cited_patent_category': u'cited by examine...
# 98370  [{u'cited_patent_category': u'cited by examine...
# 70                    [{u'cited_patent_category': None}]
# 98380  [{u'cited_patent_category': u'cited by examine...
# 84       [{u'cited_patent_category': u'cited by other'}]
# 65624  [{u'cited_patent_category': u'cited by examine...
# 93       [{u'cited_patent_category': u'cited by other'}]
# 98399  [{u'cited_patent_category': u'cited by applica...
# 96       [{u'cited_patent_category': u'cited by other'}]
# 99     [{u'cited_patent_category': u'cited by other'}...
# 100    [{u'cited_patent_category': u'cited by examine...
# ...                                                  ...
# 65257  [{u'cited_patent_category': u'cited by examine...
# 65260  [{u'cited_patent_category': u'cited by applica...
# 98037  [{u'cited_patent_category': u'cited by examine...
# 98038  [{u'cited_patent_category': u'cited by applica...
# 65273  [{u'cited_patent_category': u'cited by examine...
# 65274  [{u'cited_patent_category': u'cited by examine...
# 98041  [{u'cited_patent_category': u'cited by examine...
# 65278  [{u'cited_patent_category': u'cited by examine...
# 65284  [{u'cited_patent_category': u'cited by examine...
# 65286  [{u'cited_patent_category': u'cited by examine...
# 65287  [{u'cited_patent_category': u'cited by examine...
# 65306  [{u'cited_patent_category': u'cited by examine...
# 65307  [{u'cited_patent_category': u'cited by examine...
# 65312  [{u'cited_patent_category': u'cited by examine...
# 98096  [{u'cited_patent_category': u'cited by applica...
# 98100  [{u'cited_patent_category': u'cited by examine...
# 65336  [{u'cited_patent_category': u'cited by applica...
# 65345  [{u'cited_patent_category': u'cited by examine...
# 65360  [{u'cited_patent_category': u'cited by applica...
# 65401  [{u'cited_patent_category': u'cited by applica...
# 65402  [{u'cited_patent_category': u'cited by applica...
# 65423                 [{u'cited_patent_category': None}]
# 65424  [{u'cited_patent_category': u'cited by examine...
# 98199  [{u'cited_patent_category': u'cited by applica...
# 65448  [{u'cited_patent_category': u'cited by examine...
# 65485  [{u'cited_patent_category': u'cited by examine...
# 98256  [{u'cited_patent_category': u'cited by applica...
# 98258  [{u'cited_patent_category': u'cited by applica...
# 65500  [{u'cited_patent_category': u'cited by examine...
# 65535  [{u'cited_patent_category': u'cited by examine...
#
#                                                     cpcs  \
# 65556  [{u'cpc_subgroup_title': u'Accessing, addressi...
# 98325  [{u'cpc_subgroup_title': u'Digital computing o...
# 28     [{u'cpc_subgroup_title': u'Digital computing o...
# 29     [{u'cpc_subgroup_title': u'Administration; Man...
# 98334  [{u'cpc_subgroup_title': u'Arrangements for pr...
# 30     [{u'cpc_subgroup_title': u'Commerce, e.g. shop...
# 35     [{u'cpc_subgroup_title': u'Arrangements for pr...
# 65580  [{u'cpc_subgroup_title': u'Arrangements for pr...
# 49     [{u'cpc_subgroup_title': u'Administration; Man...
# 50     [{u'cpc_subgroup_title': u'Arrangements for pr...
# 51     [{u'cpc_subgroup_title': u'Digital computing o...
# 65586  [{u'cpc_subgroup_title': u'Security arrangemen...
# 53     [{u'cpc_subgroup_title': u'Details of televisi...
# 54     [{u'cpc_subgroup_title': u'Administration; Man...
# 56     [{u'cpc_subgroup_title': u'Nanotechnology for ...
# 58     [{u'cpc_subgroup_title': u'Digital computing o...
# 64     [{u'cpc_subgroup_title': u'Methods or arrangem...
# 65     [{u'cpc_subgroup_title': u'Light guides-of the...
# 66     [{u'cpc_subgroup_title': u'Control of exposure...
# 65600  [{u'cpc_subgroup_title': u'Administration; Man...
# 98370  [{u'cpc_subgroup_title': u'Methods or arrangem...
# 70     [{u'cpc_subgroup_title': u'Digital computing o...
# 98380  [{u'cpc_subgroup_title': u'Speech recognition ...
# 84     [{u'cpc_subgroup_title': u'Digital computing o...
# 65624  [{u'cpc_subgroup_title': u'Arrangements for pr...
# 93     [{u'cpc_subgroup_title': u'Video games, i.e. g...
# 98399  [{u'cpc_subgroup_title': u'Digital computing o...
# 96     [{u'cpc_subgroup_title': u'Administration; Man...
# 99     [{u'cpc_subgroup_title': u'Automatic systems i...
# 100    [{u'cpc_subgroup_title': u'Stereoscopic video ...
# ...                                                  ...
# 65257  [{u'cpc_subgroup_title': u'Input arrangements ...
# 65260  [{u'cpc_subgroup_title': u'Speech recognition ...
# 98037  [{u'cpc_subgroup_title': u'Arrangements for pr...
# 98038  [{u'cpc_subgroup_title': u'Administration; Man...
# 65273  [{u'cpc_subgroup_title': u'Digital computing o...
# 65274  [{u'cpc_subgroup_title': u'Speech recognition ...
# 98041  [{u'cpc_subgroup_title': u'Accessing, addressi...
# 65278  [{u'cpc_subgroup_title': u'Services specially ...
# 65284  [{u'cpc_subgroup_title': u'Arrangements for pr...
# 65286  [{u'cpc_subgroup_title': u'Accessing, addressi...
# 65287  [{u'cpc_subgroup_title': u'Digital computing o...
# 65306  [{u'cpc_subgroup_title': u'Digital computing o...
# 65307  [{u'cpc_subgroup_title': u'Security arrangemen...
# 65312  [{u'cpc_subgroup_title': u'Navigation; Navigat...
# 98096  [{u'cpc_subgroup_title': u'Editing; Indexing; ...
# 98100  [{u'cpc_subgroup_title': u'Preventing the form...
# 65336  [{u'cpc_subgroup_title': u'Administration; Man...
# 65345  [{u'cpc_subgroup_title': u'Digital computing o...
# 65360  [{u'cpc_subgroup_title': u'Animation-3D [Three...
# 65401  [{u'cpc_subgroup_title': u'Digital computing o...
# 65402  [{u'cpc_subgroup_title': u'Security arrangemen...
# 65423  [{u'cpc_subgroup_title': u'Arrangements for so...
# 65424  [{u'cpc_subgroup_title': u'Accessing, addressi...
# 98199  [{u'cpc_subgroup_title': u'Arrangements for pr...
# 65448  [{u'cpc_subgroup_title': u'Interconnection of,...
# 65485  [{u'cpc_subgroup_title': u'Arrangements for pr...
# 98256  [{u'cpc_subgroup_title': u'Systems or methods ...
# 98258  [{u'cpc_subgroup_title': u'Commerce, e.g. shop...
# 65500  [{u'cpc_subgroup_title': u'Error detection; Er...
# 65535  [{u'cpc_subgroup_title': u'Error detection; Er...
#
#                                                inventors  \
# 65556  [{u'inventor_key_id': u'20711', u'inventor_cit...
# 98325  [{u'inventor_key_id': u'10669', u'inventor_cit...
# 28     [{u'inventor_key_id': u'9872', u'inventor_city...
# 29     [{u'inventor_key_id': u'202058', u'inventor_ci...
# 98334  [{u'inventor_key_id': u'5805', u'inventor_city...
# 30     [{u'inventor_key_id': u'9507', u'inventor_city...
# 35     [{u'inventor_key_id': u'222902', u'inventor_ci...
# 65580  [{u'inventor_key_id': u'1323365', u'inventor_c...
# 49     [{u'inventor_key_id': u'2412288', u'inventor_c...
# 50     [{u'inventor_key_id': u'181551', u'inventor_ci...
# 51     [{u'inventor_key_id': u'103148', u'inventor_ci...
# 65586  [{u'inventor_key_id': u'39989', u'inventor_cit...
# 53     [{u'inventor_key_id': u'79535', u'inventor_cit...
# 54     [{u'inventor_key_id': u'1660293', u'inventor_c...
# 56     [{u'inventor_key_id': u'125721', u'inventor_ci...
# 58     [{u'inventor_key_id': u'2030451', u'inventor_c...
# 64     [{u'inventor_key_id': u'21532', u'inventor_cit...
# 65     [{u'inventor_key_id': u'1923018', u'inventor_c...
# 66     [{u'inventor_key_id': u'201862', u'inventor_ci...
# 65600  [{u'inventor_key_id': u'1536681', u'inventor_c...
# 98370  [{u'inventor_key_id': u'64570', u'inventor_cit...
# 70     [{u'inventor_key_id': u'1385425', u'inventor_c...
# 98380  [{u'inventor_key_id': u'182058', u'inventor_ci...
# 84     [{u'inventor_key_id': u'2404032', u'inventor_c...
# 65624  [{u'inventor_key_id': u'1322101', u'inventor_c...
# 93     [{u'inventor_key_id': u'173403', u'inventor_ci...
# 98399  [{u'inventor_key_id': u'190497', u'inventor_ci...
# 96     [{u'inventor_key_id': u'35463', u'inventor_cit...
# 99     [{u'inventor_key_id': u'2432812', u'inventor_c...
# 100    [{u'inventor_key_id': u'2432883', u'inventor_c...
# ...                                                  ...
# 65257  [{u'inventor_key_id': u'2461530', u'inventor_c...
# 65260  [{u'inventor_key_id': u'21695', u'inventor_cit...
# 98037  [{u'inventor_key_id': u'20321', u'inventor_cit...
# 98038  [{u'inventor_key_id': u'215062', u'inventor_ci...
# 65273  [{u'inventor_key_id': u'10380', u'inventor_cit...
# 65274  [{u'inventor_key_id': u'3266759', u'inventor_c...
# 98041  [{u'inventor_key_id': u'181843', u'inventor_ci...
# 65278  [{u'inventor_key_id': u'10243', u'inventor_cit...
# 65284  [{u'inventor_key_id': u'20872', u'inventor_cit...
# 65286  [{u'inventor_key_id': u'630928', u'inventor_ci...
# 65287  [{u'inventor_key_id': u'3269194', u'inventor_c...
# 65306  [{u'inventor_key_id': u'118922', u'inventor_ci...
# 65307  [{u'inventor_key_id': u'214623', u'inventor_ci...
# 65312  [{u'inventor_key_id': u'3066761', u'inventor_c...
# 98096  [{u'inventor_key_id': u'9508', u'inventor_city...
# 98100  [{u'inventor_key_id': u'6260', u'inventor_city...
# 65336  [{u'inventor_key_id': u'102331', u'inventor_ci...
# 65345  [{u'inventor_key_id': u'1157808', u'inventor_c...
# 65360  [{u'inventor_key_id': u'9509', u'inventor_city...
# 65401  [{u'inventor_key_id': u'10669', u'inventor_cit...
# 65402  [{u'inventor_key_id': u'2528185', u'inventor_c...
# 65423  [{u'inventor_key_id': u'119515', u'inventor_ci...
# 65424  [{u'inventor_key_id': u'20737', u'inventor_cit...
# 98199  [{u'inventor_key_id': u'92068', u'inventor_cit...
# 65448  [{u'inventor_key_id': u'35322', u'inventor_cit...
# 65485  [{u'inventor_key_id': u'79535', u'inventor_cit...
# 98256  [{u'inventor_key_id': u'10244', u'inventor_cit...
# 98258  [{u'inventor_key_id': u'9507', u'inventor_city...
# 65500  [{u'inventor_key_id': u'10309', u'inventor_cit...
# 65535  [{u'inventor_key_id': u'78510', u'inventor_cit...
#
#                                                    nbers  \
# 65556  [{u'nber_category_title': None, u'nber_subcate...
# 98325  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 28     [{u'nber_category_title': None, u'nber_subcate...
# 29     [{u'nber_category_title': None, u'nber_subcate...
# 98334  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 30     [{u'nber_category_title': None, u'nber_subcate...
# 35     [{u'nber_category_title': None, u'nber_subcate...
# 65580  [{u'nber_category_title': None, u'nber_subcate...
# 49     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 50     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 51     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65586  [{u'nber_category_title': None, u'nber_subcate...
# 53     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 54     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 56     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 58     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 64     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 66     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65600  [{u'nber_category_title': None, u'nber_subcate...
# 98370  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 70     [{u'nber_category_title': u'Elec', u'nber_subc...
# 98380  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 84     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65624  [{u'nber_category_title': None, u'nber_subcate...
# 93     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 98399  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 96     [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 99     [{u'nber_category_title': u'Elec', u'nber_subc...
# 100    [{u'nber_category_title': u'Elec', u'nber_subc...
# ...                                                  ...
# 65257  [{u'nber_category_title': None, u'nber_subcate...
# 65260  [{u'nber_category_title': None, u'nber_subcate...
# 98037  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 98038  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65273  [{u'nber_category_title': None, u'nber_subcate...
# 65274  [{u'nber_category_title': None, u'nber_subcate...
# 98041  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65278  [{u'nber_category_title': None, u'nber_subcate...
# 65284  [{u'nber_category_title': None, u'nber_subcate...
# 65286  [{u'nber_category_title': None, u'nber_subcate...
# 65287  [{u'nber_category_title': None, u'nber_subcate...
# 65306  [{u'nber_category_title': None, u'nber_subcate...
# 65307  [{u'nber_category_title': None, u'nber_subcate...
# 65312  [{u'nber_category_title': None, u'nber_subcate...
# 98096  [{u'nber_category_title': u'Elec', u'nber_subc...
# 98100  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65336  [{u'nber_category_title': None, u'nber_subcate...
# 65345  [{u'nber_category_title': None, u'nber_subcate...
# 65360  [{u'nber_category_title': None, u'nber_subcate...
# 65401  [{u'nber_category_title': None, u'nber_subcate...
# 65402  [{u'nber_category_title': None, u'nber_subcate...
# 65423  [{u'nber_category_title': None, u'nber_subcate...
# 65424  [{u'nber_category_title': None, u'nber_subcate...
# 98199  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65448  [{u'nber_category_title': None, u'nber_subcate...
# 65485  [{u'nber_category_title': None, u'nber_subcate...
# 98256  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 98258  [{u'nber_category_title': u'Cmp&Cmm', u'nber_s...
# 65500  [{u'nber_category_title': None, u'nber_subcate...
# 65535  [{u'nber_category_title': None, u'nber_subcate...
#
#                                          patent_abstract patent_id  \
# 65556  A method, system, and computer program product...   9430395
# 98325  A method and system are disclosed for use with...   8744994
# 28     An instructional design tool is provided for d...  10095805
# 29     The present disclosure relates to methods and ...  10095990
# 98334  A method is presented for executing complex op...   8745510
# 30     In various embodiments, the proximity of an av...  10096032
# 35     A method and system for integrated server-stor...  10108460
# 65580  Schema information is provided with transmissi...   9448812
# 49     A system is provided for remotely configuring ...   7386595
# 50     A system for implementing dynamic lifetime rel...   7386851
# 51     A scale-out supercomputing environment include...   7389310
# 65586  A system, method and computer program product ...   9449190
# 53     A digital camera system includes an input memb...   7391886
# 54     A method for providing transparent participati...   7392290
# 56     A data storage system having a positioning sys...   7397754
# 58     A method for searching a document collection i...   7401073
# 64     A method is provided clustering data points in...   7406200
# 65     An optical structure includes a substrate, a c...   7406226
# 66     A method for turning on the power of a camera ...   7406259
# 65600  A process definition entered into a user inter...   9454737
# 98370  A computer implemented method, apparatus, and ...   8749570
# 70     A method for designing shielding in integrated...   7409662
# 98380  A system and method for automatic call segment...   8750489
# 84     The invention is directed to a system for mana...   7420702
# 65624  A method for remote product invocation include...   9471406
# 93     A method of identifying a specific object repr...   7427980
# 98399  A method, system and computer-readable medium ...   8751536
# 96     A system is presented to allow users in an ins...   7428702
# 99     A circuit to generate a bias voltage, the circ...   7429850
# 100    Since a continuous movie effect is created at ...   7430018
# ...                                                  ...       ...
# 65257  Embodiments of the present invention provide a...   9280286
# 65260  Systems, methods and media for determining a p...   9282176
# 98037  A method, system and computer-usable medium ar...   8719300
# 98038  The disclosure is directed to email addressee ...   8719350
# 65273  In some embodiments, a method comprises detect...   9286400
# 65274  Embodiments of the present invention address d...   9286893
# 98041  Method and apparatus for handling page protect...   8719541
# 65278  Methods and apparatus, including computer prog...   9288654
# 65284  Methods, systems and computer program products...   9292303
# 65286  The allocation of virtual memory within a virt...   9292437
# 65287  Text is intelligently annotated by first creat...   9292483
# 65306  Improved visual context management techniques ...   9298855
# 65307  A method, system, and program product for remo...   9298922
# 65312  Embodiments of the present invention address d...   9301088
# 98096  A method and system for managing multiple user...   8724964
# 98100  A method, a data processing system, and a comp...   8725458
# 65336  When a user reading a received e-mail message ...   9311626
# 65345  Techniques are disclosed for analyzing a â€œco...   9317589
# 65360  A method of rendering an electronic graphical ...   9324173
# 65401  Techniques for reducing a number of computatio...   9348884
# 65402  A computer implemented method, a computer prog...   9348991
# 65423  Virtual Machine (VM) images in a virtualized e...   9361089
# 65424  Systems and methods for distributed shared cac...   9361229
# 98199  Among other things, the disclosure is applied ...   8732716
# 65448  An I/O device obtains multiple unique N_Port I...   9372819
# 65485  Embodiments of the invention provide a method ...   9389918
# 98256  Methods, devices and systems are provided for ...   8738430
# 98258  A method implemented in a computer infrastruct...   8738432
# 65500  A method for controlling a computer-implemente...   9396099
# 65535  A load store advisory program sets a breakpoin...   9417987
#
#       patent_type                                              uspcs  \
# 65556     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98325     utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 28        utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 29        utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98334     utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 30        utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 35        utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65580     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 49        utility  [{u'uspc_mainclass_title': u'Electrical comput...
# 50        utility  [{u'uspc_mainclass_title': u'Electrical comput...
# 51        utility  [{u'uspc_mainclass_title': u'Unclassified', u'...
# 65586     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 53        utility  [{u'uspc_mainclass_title': u'Television', u'us...
# 54        utility  [{u'uspc_mainclass_title': u'Electrical comput...
# 56        utility  [{u'uspc_mainclass_title': u'Dynamic informati...
# 58        utility  [{u'uspc_mainclass_title': u'Unclassified', u'...
# 64        utility  [{u'uspc_mainclass_title': u'Image analysis', ...
# 65        utility  [{u'uspc_mainclass_title': u'Coherent light ge...
# 66        utility  [{u'uspc_mainclass_title': u'Photography', u'u...
# 65600     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98370     utility  [{u'uspc_mainclass_title': u'Computer graphics...
# 70        utility  [{u'uspc_mainclass_title': u'Computer-aided de...
# 98380     utility  [{u'uspc_mainclass_title': u'Telephonic commun...
# 84        utility  [{u'uspc_mainclass_title': u'Facsimile and sta...
# 65624     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 93        utility  [{u'uspc_mainclass_title': u'Amusement devices...
# 98399     utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 96        utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 99        utility  [{u'uspc_mainclass_title': u'Electricity:  pow...
# 100       utility  [{u'uspc_mainclass_title': u'Computer graphics...
# ...           ...                                                ...
# 65257     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65260     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98037     utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 98038     utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 65273     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65274     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98041     utility  [{u'uspc_mainclass_title': u'Electrical comput...
# 65278     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65284     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65286     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65287     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65306     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65307     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65312     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98096     utility  [{u'uspc_mainclass_title': u'Communications:  ...
# 98100     utility  [{u'uspc_mainclass_title': u'Active solid-stat...
# 65336     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65345     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65360     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65401     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65402     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65423     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65424     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98199     utility  [{u'uspc_mainclass_title': u'Electrical comput...
# 65448     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65485     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 98256     utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 98258     utility  [{u'uspc_mainclass_title': u'Data processing: ...
# 65500     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
# 65535     utility  [{u'uspc_mainclass_title': None, u'uspc_sequen...
#
#                                                    wipos assignee_city  \
# 65556  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 98325  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 28     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 29     [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 98334  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 30     [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 35     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65580  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 49     [{u'wipo_field_title': u'Digital communication...        Armonk
# 50     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 51     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65586  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 53     [{u'wipo_field_title': u'Audio-visual technolo...        Armonk
# 54     [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 56     [{u'wipo_field_title': u'Micro-structural and ...        Armonk
# 58     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 64     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65     [{u'wipo_field_title': u'Optics', u'wipo_secto...        Armonk
# 66     [{u'wipo_field_title': u'Optics', u'wipo_secto...        Armonk
# 65600  [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 98370  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 70     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 98380  [{u'wipo_field_title': u'Telecommunications', ...        Armonk
# 84     [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65624  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 93     [{u'wipo_field_title': u'Furniture, games', u'...        Armonk
# 98399  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 96     [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 99     [{u'wipo_field_title': u'Control', u'wipo_sect...        Armonk
# 100    [{u'wipo_field_title': u'Audio-visual technolo...        Armonk
# ...                                                  ...           ...
# 65257  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65260  [{u'wipo_field_title': u'Telecommunications', ...        Armonk
# 98037  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 98038  [{u'wipo_field_title': u'Digital communication...        Armonk
# 65273  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65274  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 98041  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65278  [{u'wipo_field_title': u'Telecommunications', ...        Armonk
# 65284  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65286  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65287  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65306  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65307  [{u'wipo_field_title': u'Digital communication...        Armonk
# 65312  [{u'wipo_field_title': u'Control', u'wipo_sect...        Armonk
# 98096  [{u'wipo_field_title': u'Audio-visual technolo...        Armonk
# 98100  [{u'wipo_field_title': u'Semiconductors', u'wi...        Armonk
# 65336  [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 65345  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65360  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65401  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65402  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65423  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65424  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 98199  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65448  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65485  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 98256  [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 98258  [{u'wipo_field_title': u'IT methods for manage...        Armonk
# 65500  [{u'wipo_field_title': u'Computer technology',...        Armonk
# 65535  [{u'wipo_field_title': u'Computer technology',...        Armonk
#
#                         field                  sector   ipc_section
# 65556  Electrical engineering  Electrical engineering        [u'G']
# 98325  Electrical engineering  Electrical engineering        [u'G']
# 28     Electrical engineering  Electrical engineering        [u'G']
# 29     Electrical engineering  Electrical engineering        [u'G']
# 98334  Electrical engineering  Electrical engineering        [u'G']
# 30     Electrical engineering  Electrical engineering        [u'G']
# 35     Electrical engineering  Electrical engineering        [u'G']
# 65580  Electrical engineering  Electrical engineering        [u'G']
# 49     Electrical engineering  Electrical engineering        [u'G']
# 50     Electrical engineering  Electrical engineering        [u'G']
# 51     Electrical engineering  Electrical engineering        [u'G']
# 65586  Electrical engineering  Electrical engineering        [u'G']
# 53     Electrical engineering  Electrical engineering        [u'G']
# 54     Electrical engineering  Electrical engineering        [u'G']
# 56                  Chemistry               Chemistry        [u'G']
# 58     Electrical engineering  Electrical engineering        [u'G']
# 64     Electrical engineering  Electrical engineering        [u'G']
# 65                Instruments             Instruments  [u'H', u'G']
# 66                Instruments             Instruments        [u'G']
# 65600  Electrical engineering  Electrical engineering  [u'H', u'G']
# 98370  Electrical engineering  Electrical engineering        [u'G']
# 70     Electrical engineering  Electrical engineering        [u'G']
# 98380  Electrical engineering  Electrical engineering  [u'H', u'G']
# 84     Electrical engineering  Electrical engineering        [u'G']
# 65624  Electrical engineering  Electrical engineering        [u'G']
# 93                       None                    None        [u'G']
# 98399  Electrical engineering  Electrical engineering        [u'G']
# 96     Electrical engineering  Electrical engineering        [u'G']
# 99                Instruments             Instruments        [u'G']
# 100    Electrical engineering  Electrical engineering  [u'H', u'G']
# ...                       ...                     ...           ...
# 65257  Electrical engineering  Electrical engineering        [u'G']
# 65260  Electrical engineering  Electrical engineering  [u'H', u'G']
# 98037  Electrical engineering  Electrical engineering        [u'G']
# 98038  Electrical engineering  Electrical engineering        [u'G']
# 65273  Electrical engineering  Electrical engineering        [u'G']
# 65274  Electrical engineering  Electrical engineering        [u'G']
# 98041  Electrical engineering  Electrical engineering        [u'G']
# 65278  Electrical engineering  Electrical engineering  [u'H', u'G']
# 65284  Electrical engineering  Electrical engineering        [u'G']
# 65286  Electrical engineering  Electrical engineering        [u'G']
# 65287  Electrical engineering  Electrical engineering        [u'G']
# 65306  Electrical engineering  Electrical engineering        [u'G']
# 65307  Electrical engineering  Electrical engineering  [u'H', u'G']
# 65312             Instruments             Instruments  [u'H', u'G']
# 98096  Electrical engineering  Electrical engineering  [u'H', u'G']
# 98100  Electrical engineering  Electrical engineering  [u'H', u'G']
# 65336  Electrical engineering  Electrical engineering  [u'H', u'G']
# 65345  Electrical engineering  Electrical engineering        [u'G']
# 65360  Electrical engineering  Electrical engineering        [u'G']
# 65401  Electrical engineering  Electrical engineering        [u'G']
# 65402  Electrical engineering  Electrical engineering  [u'H', u'G']
# 65423  Electrical engineering  Electrical engineering        [u'G']
# 65424  Electrical engineering  Electrical engineering        [u'G']
# 98199  Electrical engineering  Electrical engineering        [u'G']
# 65448  Electrical engineering  Electrical engineering  [u'H', u'G']
# 65485  Electrical engineering  Electrical engineering        [u'G']
# 98256  Electrical engineering  Electrical engineering        [u'G']
# 98258  Electrical engineering  Electrical engineering        [u'G']
# 65500  Electrical engineering  Electrical engineering        [u'G']
# 65535  Electrical engineering  Electrical engineering        [u'G']
#
# [6962 rows x 18 columns]
