# %%
import pandas as pd
import requests

# %%
variable_dict = {'B01003_001E':'total_population',            
'B01001_002E':'total_men',
'B01001_026E':'total_women',
'B02001_002E':'total_white',
'B02001_003E':'total_black',
'B02001_004E':'total_native',
'B02001_005E':'total_asian',
'B02001_006E':'total_hawaiin',
'B02001_007E':'total_other',
'B02001_008E':'total_two_or_more',
'B03002_012E':'total_latino',
'B05002_002E':'total_native_born',                
'B05002_014E':'total_foreign_born_naturalized',
'B05002_015E':'total_foreign_born_non_citizen', 
'B23025_002E':'total_in_labour_force', 
'B15003_017E': 'total_Regular_high_school_diploma',
'B15003_018E': 'total_GED_or_alternative_credential',
'B15003_019E': 'total_Some_college_less_than_1_year',
'B15003_020E': 'total_Some_college_1_or_more_years_no_degree',
'B15003_021E': 'total_Associates_degree',
'B15003_022E': 'total_Bachelors_degree',
'B15003_023E': 'total_Masters_degree',
'B15003_024E': 'total_Professional_school_degree',
'B15003_025E': 'total_Doctorate_degree',
'B19325_006E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$1 to $2,499 or loss',
'B19325_007E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$2,500 to $4,999',
'B19325_008E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$5,000 to $7,499',
'B19325_009E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$7,500 to $9,999',
'B19325_010E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$10,000 to $12,499',
'B19325_011E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$12,500 to $14,999',
'B19325_012E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$15,000 to $17,499',
'B19325_013E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$17,500 to $19,999',
'B19325_014E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$20,000 to $22,499',
'B19325_015E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$22,500 to $24,999',
'B19325_016E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$25,000 to $29,999',
'B19325_017E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$30,000 to $34,999',
'B19325_018E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$35,000 to $39,999',
'B19325_019E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$40,000 to $44,999',
'B19325_020E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$45,000 to $49,999',
'B19325_021E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$50,000 to $54,999',
'B19325_022E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$55,000 to $64,999',
'B19325_023E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$65,000 to $74,999',
'B19325_024E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$75,000 to $99,999',
'B19325_025E' : 'Estimate!!Total!!Male!!Worked full-time, year-round in the past 12 months!!With income!!$100,000 or more',
'B19325_053E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$1 to $2,499 or loss',
'B19325_054E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$2,500 to $4,999',
'B19325_055E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$5,000 to $7,499',
'B19325_056E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$7,500 to $9,999',
'B19325_057E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$10,000 to $12,499',
'B19325_058E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$12,500 to $14,999',
'B19325_059E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$15,000 to $17,499',
'B19325_060E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$17,500 to $19,999',
'B19325_061E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$20,000 to $22,499',
'B19325_062E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$22,500 to $24,999',
'B19325_063E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$25,000 to $29,999',
'B19325_064E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$30,000 to $34,999',
'B19325_065E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$35,000 to $39,999',
'B19325_066E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$40,000 to $44,999',
'B19325_067E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$45,000 to $49,999',
'B19325_068E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$50,000 to $54,999',
'B19325_069E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$55,000 to $64,999',
'B19325_070E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$65,000 to $74,999',
'B19325_071E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$75,000 to $99,999',
'B19325_072E' : 'Estimate!!Total!!Female!!Worked full-time, year-round in the past 12 months!!With income!!$100,000 or more'}

# %%
r = requests.get('https://api.census.gov/data/2010/acs/acs5?get=NAME,B01001_002E,B01001_026E,B02001_002E,B02001_003E,B02001_004E,B02001_005E,B02001_006E,B02001_007E,B02001_008E,B03002_012E,B05002_002E,B05002_014E,B05002_015E,B19325_006E,B19325_007E,B19325_008E,B19325_009E,B19325_010E,B19325_011E,B19325_012E,B19325_013E,B19325_014E,B19325_015E,B19325_016E,B19325_017E,B19325_018E,B19325_019E,B19325_020E,B19325_021E,B19325_022E,B19325_023E,B19325_024E,B19325_025E,B19325_053E,B19325_054E,B19325_055E,B19325_056E,B19325_057E,B19325_058E,B19325_059E,B19325_060E,B19325_061E,B19325_062E,B19325_063E,B19325_064E,B19325_065E,B19325_066E,B19325_067E&for=place:*')

# %%
data1 = r.json()[1:]
schema1 = r.json()[0]

# %%
df = pd.DataFrame(data1)
df.columns = schema1
df.head()
# Out:
#                        NAME B01001_002E B01001_026E B02001_002E B02001_003E  \
# 0       Abanda CDP, Alabama          21          22          33          10
# 1   Abbeville city, Alabama        1352        1388        1349        1058
# 2  Adamsville city, Alabama        2416        2183        2797        1617
# 3     Addison town, Alabama         455         459         872           0
# 4       Akron town, Alabama         193         320         149         342
#
#   B02001_004E B02001_005E B02001_006E B02001_007E B02001_008E  ...    \
# 0           0           0           0           0           0  ...
# 1           0         275           0          51           7  ...
# 2           0          23           0          79          83  ...
# 3           0           0           0           0          42  ...
# 4           0           0           0           0          22  ...
#
#   B19325_060E B19325_061E B19325_062E B19325_063E B19325_064E B19325_065E  \
# ...

# %%
r2 = requests.get('https://api.census.gov/data/2010/acs/acs5?get=NAME,B19325_068E,B19325_069E,B19325_070E,B19325_071E,B19325_072E&for=place:*')

# %%
data2 = r2.json()[1:]
schema2 = r2.json()[0]

# %%
df2 = pd.DataFrame(data2)
df2.columns = schema2
df2.head()
# Out:
#                        NAME B19325_068E B19325_069E B19325_070E B19325_071E  \
# 0       Abanda CDP, Alabama           0           0           0           0
# 1   Abbeville city, Alabama           0          26           0           0
# 2  Adamsville city, Alabama          57          30          24           0
# 3     Addison town, Alabama           0           0           0           0
# 4       Akron town, Alabama           0           0           0           0
#
#   B19325_072E state  place
# 0           0    01  00100
# 1           0    01  00124
# 2           0    01  00460
# 3           0    01  00484
# 4           0    01  00676

# %%
all_demo_data = df.merge(df2, left_on = 'NAME', right_on = 'NAME', how = 'outer')

# %%
all_demo_data
# Out:
#                                                  NAME B01001_002E B01001_026E  \
# 0                                 Abanda CDP, Alabama          21          22
# 1                             Abbeville city, Alabama        1352        1388
# 2                            Adamsville city, Alabama        2416        2183
# 3                               Addison town, Alabama         455         459
# 4                                 Akron town, Alabama         193         320
# 5                             Alabaster city, Alabama       14469       15081
# 6                           Albertville city, Alabama       10213       10232
# 7                        Alexander City city, Alabama        7063        7816
# 8                             Alexandria CDP, Alabama        1933        1812
# 9                            Aliceville city, Alabama        1413        1688
# 10                              Allgood town, Alabama         327         388
# ...

# %%
all_demo_data['city_name'] = pd.np.where(all_demo_data.NAME.str.contains("city"),
                                                         all_demo_data.NAME.str.split("city"),
                                             pd.np.where(all_demo_data.NAME.str.contains("CDP"),
                                                         all_demo_data.NAME.str.split("CDP"),
                                             pd.np.where(all_demo_data.NAME.str.contains("town"),
                                                         all_demo_data.NAME.str.split("town"), 
                                                         "task")))

# %%
all_demo_data
# Out:
#                                                  NAME B01001_002E B01001_026E  \
# 0                                 Abanda CDP, Alabama          21          22
# 1                             Abbeville city, Alabama        1352        1388
# 2                            Adamsville city, Alabama        2416        2183
# 3                               Addison town, Alabama         455         459
# 4                                 Akron town, Alabama         193         320
# 5                             Alabaster city, Alabama       14469       15081
# 6                           Albertville city, Alabama       10213       10232
# 7                        Alexander City city, Alabama        7063        7816
# 8                             Alexandria CDP, Alabama        1933        1812
# 9                            Aliceville city, Alabama        1413        1688
# 10                              Allgood town, Alabama         327         388
# ...

# %%
all_demo_data['state_name'] = all_demo_data['city_name'].str[1]

# %%
all_demo_data['city_name'] = all_demo_data['city_name'].str[0]

# %%
#all_demo_data['city_name'] = all_demo_data['city_name'].str.replace('[','')

# %%
all_demo_data['state_name'] = all_demo_data['state_name'].str.replace(',','')

# %%
all_demo_data['state_name'] = all_demo_data['state_name'].str.lower()
all_demo_data['city_name'] = all_demo_data['city_name'].str.lower()

# %%
all_demo_data['city_state'] = all_demo_data['city_name'] + '_' + all_demo_data['state_name']

# %%
all_demo_data['city_state'] = all_demo_data['city_state'].str.replace(' ','')

# %%
all_demo_data.columns
# Out:
# Index(['NAME', 'B01001_002E', 'B01001_026E', 'B02001_002E', 'B02001_003E',
#        'B02001_004E', 'B02001_005E', 'B02001_006E', 'B02001_007E',
#        'B02001_008E', 'B03002_012E', 'B05002_002E', 'B05002_014E',
#        'B05002_015E', 'B19325_006E', 'B19325_007E', 'B19325_008E',
#        'B19325_009E', 'B19325_010E', 'B19325_011E', 'B19325_012E',
#        'B19325_013E', 'B19325_014E', 'B19325_015E', 'B19325_016E',
#        'B19325_017E', 'B19325_018E', 'B19325_019E', 'B19325_020E',
#        'B19325_021E', 'B19325_022E', 'B19325_023E', 'B19325_024E',
#        'B19325_025E', 'B19325_053E', 'B19325_054E', 'B19325_055E',
#        'B19325_056E', 'B19325_057E', 'B19325_058E', 'B19325_059E',
#        'B19325_060E', 'B19325_061E', 'B19325_062E', 'B19325_063E',
#        'B19325_064E', 'B19325_065E', 'B19325_066E', 'B19325_067E', 'state_x',
#        'place_x', 'B19325_068E', 'B19325_069E', 'B19325_070E', 'B19325_071E',
#        'B19325_072E', 'state_y', 'place_y', 'city_name', 'state_name',
# ...

# %%
new_columns = ['NAME','total_men','total_women','total_white','total_black','total_native','total_asian',
                        'total_hawaiin','total_other','total_two_or_more_races','total_latino','total_native_born',
                        'total_foreign_born_naturalized','total_foreign_born_non_citizen','total_men_earning_2499_or_less',
                        'total_men_earning_2500_4999','total_men_earning_5000_7499','total_men_earning_7500_9999',
                        'total_men_earning_10000_12999','total_men_earning_12500_14999','total_men_earning_15000_17499',
                        'total_men_earning_17500,19999','total_men_earning_20000_22499','total_men_earning_22500_24999',
                        'total_men_earning_25000_29999','total_men_earning_30000_34999','total_men_earning_35000_39999',
                        'total_men_earning_40000_44999','total_men_earning_45000_49999','total_men_earning_50000_54999',
                        'total_men_earning_55000_64999','total_men_earning_65000_74999','total_men_earning_75000_99999',
                        'total_men_earning_100000_plus','total_women_earning_2499_or_less',
                        'total_women_earning_2500_4999','total_women_earning_5000_7499','total_women_earning_7500_9999',
                        'total_women_earning_10000_12999','total_women_earning_12500_14999','total_women_earning_15000_17499',
                        'total_women_earning_17500,19999','total_women_earning_20000_22499','total_women_earning_22500_24999',
                        'total_women_earning_25000_29999','total_women_earning_30000_34999','total_women_earning_35000_39999',
                        'state_x','place_x','total_women_earning_40000_44999','total_women_earning_45000_49999',
                        'total_women_earning_50000_54999','total_women_earning_55000_64999','total_women_earning_65000_74999',
                        'total_women_earning_75000_99999','total_women_earning_100000_plus','state', 'place', 
                        'city_name', 'state_name','city_state']

# %%
all_demo_data.columns = new_columns

# %%
all_demo_data
# Out:
#                                                  NAME total_men total_women  \
# 0                                 Abanda CDP, Alabama        21          22
# 1                             Abbeville city, Alabama      1352        1388
# 2                            Adamsville city, Alabama      2416        2183
# 3                               Addison town, Alabama       455         459
# 4                                 Akron town, Alabama       193         320
# 5                             Alabaster city, Alabama     14469       15081
# 6                           Albertville city, Alabama     10213       10232
# 7                        Alexander City city, Alabama      7063        7816
# 8                             Alexandria CDP, Alabama      1933        1812
# 9                            Aliceville city, Alabama      1413        1688
# 10                              Allgood town, Alabama       327         388
# ...

# %%
all_demo_data.to_csv('2012_demo_data.csv')
