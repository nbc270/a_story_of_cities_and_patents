# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Get Datasets

# %% [markdown]
# ## Patents

# %%
cities = pd.read_csv('Patents_Data/cities_with_scores.csv')

# %%
cities.head()
# Out:
#    Unnamed: 0     city_state  Year    Score1    Score2    Score5    Score6  \
# 0           0    New York_NY  1976  2.317268  2.718282  2.360150  2.718282
# 1           1  Washington_DC  1976  1.558923  2.219101  1.738496  2.412346
# 2           2  Pittsburgh_PA  1976  2.718282  2.425776  2.564047  2.369092
# 3           3     Chicago_IL  1976  2.639930  2.393199  2.560876  2.358395
# 4           4    Stamford_CT  1976  2.167678  2.186224  2.135113  2.301236
#
#      Score7        City State
# 0  5.078432    New York    NY
# 1  4.150842  Washington    DC
# 2  4.933139  Pittsburgh    PA
# 3  4.919271     Chicago    IL
# 4  4.436350    Stamford    CT

# %%
cities.shape
# Out:
# (38573, 10)

# %%
cities_2012 = cities.loc[cities['Year']==2012]

# %%
cities_2012.shape
# Out:
# (972, 10)

# %%
cities_2012['city_state'] = cities_2012['city_state'].str.replace(' ','')
cities_2012['city_state'] = cities_2012['city_state'].str.replace(',','')
cities_2012['city_state'] = cities_2012['city_state'].str.replace('.','')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# ...

# %%
cities_2012['city_state'] = cities_2012['city_state'].str.lower()
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## SBIR

# %%
sbir = pd.read_csv('Regulation_Data/SBIR/sbir_city_2012.csv')

# %%
sbir.head()
# Out:
#    Unnamed: 0       City_State  Award Mean  Award Sum  Company Count  \
# 0           0       Addison_TX     99261.0    99261.0              1
# 1           1      Adelanto_CA    134990.4   674952.0              5
# 2           2      Adelphia_NJ     99100.0    99100.0              1
# 3           3  Agoura hills_CA    149900.0   449700.0              3
# 4           4          Aiea_HI    315449.5   630899.0              2
#
#            City State
# 0       Addison    TX
# 1      Adelanto    CA
# 2      Adelphia    NJ
# 3  Agoura hills    CA
# 4          Aiea    HI

# %%
sbir.shape
# Out:
# (1115, 7)

# %%
sbir['City_State'] = sbir['City_State'].str.replace(' ','')
sbir['City_State'] = sbir['City_State'].str.replace(',','')
sbir['City_State'] = sbir['City_State'].str.replace('.','')

# %%
sbir['City_State'] = sbir['City_State'].str.lower()

# %% [markdown]
# ## Econ

# %%
econ = pd.read_csv('econ_data/2012_creative_class.csv')

# %%
econ.head()
# Out:
#    Unnamed: 0                   city_state  creative_employees  \
# 0           0                Abbeville _AL                 0.0
# 1           1                Abbeville _GA                 0.0
# 2           2                Abbeville _LA               288.0
# 3           3                Abbeville _SC                33.0
# 4           4  Aberdeen Proving Ground _MD                 0.0
#
#    regular_employees  creative_establishments  regular_establishments  \
# 0              522.0                     12.0                   147.0
# 1               84.0                      0.0                    20.0
# 2             2427.0                    120.0                   679.0
# 3               58.0                     20.0                   187.0
# 4             5322.0                     35.0                   381.0
#
#    percent_creative_class
# 0                0.000000
# 1                0.000000
# 2               10.607735
# 3               36.263736
# 4                0.000000

# %%
econ['city_state'] = econ['city_state'].str.replace(' ','')

# %%
econ['city_state'] = econ['city_state'].str.replace('.','')
econ['city_state'] = econ['city_state'].str.replace(',','')

# %%
econ['city_state'] = econ['city_state'].str.lower()

# %%
econ['percent_creative_class'] = (econ['creative_employees']/(econ['creative_employees']+econ['regular_employees']))*100

# %% [markdown]
# ## Demographics

# %% [markdown]
# # Begin Joins

# %%
#sbir with patents data
sbir_cities = cities_2012.merge(sbir, left_on = 'city_state', right_on = 'City_State', how = 'left')

# %%
sbir_creative_cities = sbir_cities.merge(econ,left_on = 'city_state', right_on = 'city_state', how = 'left')

# %%
sbir_creative_cities.sort_values('percent_creative_class', ascending =False)
# Out:
#      Unnamed: 0_x             city_state  Year    Score1    Score2    Score5  \
# 441         36107             saginaw_mi  2012  1.772433  1.785794  1.668531
# 501         36167            iowacity_ia  2012  1.807262  1.818767  1.638461
# 160         35828         gainesville_fl  2012  1.974907  1.998535  1.831523
# 48          35716            hartford_ct  2012  1.708347  2.016487  1.560088
# 57          35725              peoria_il  2012  1.895665  2.025270  1.870020
# 598         36264            greenbay_wi  2012  1.626007  1.631330  1.483187
# 52          35720         auburnhills_mi  2012  1.588965  2.065905  1.520044
# 576         36242          charleston_sc  2012  1.640622  1.670646  1.504558
# 106         35774               akron_oh  2012  1.896601  1.962083  1.831523
# 30          35698           menlopark_ca  2012  2.411400  2.505600  2.261464
# 867         36533          wallawalla_wa  2012  1.582761  1.591405  1.336830
# ...

# %%
sbir_creative_cities[~sbir_creative_cities['percent_creative_class'].isnull()].shape
# Out:
# (788, 23)

# %%
sbir_creative_cities.to_csv('sbir_creative_cities.csv')
